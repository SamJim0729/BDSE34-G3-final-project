# %% [markdown]
# ## colab setting ,read file and import module
# * 注意此次資料集為lag5(以前五個月預測當月)，若要其他月份要重切，到時候有空再研究有沒有辦法當場切

# %%
#!pip install google.colab #如未安裝取消註解後執行
import os
from google.colab import drive
drive.mount('/content/my_drive')
# Out:
# Mounted at /content/my_drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
# file_path = '/content/my_drive/MyDrive/BDSE34期末報告_房價/all_data/detailed_usage_data_for_NNs.csv'
file_path = '/content/my_drive/MyDrive/BDSE34期末報告_房價/all_data/c591_final_detailed_usage_full_main_data_for_xgb_v2.csv'
df = pd.read_csv(file_path)

# %%
import numpy as np
import joblib
import pandas as pd
import datetime
import tensorflow as tf
import os
import random
import timeit

import seaborn as sns
import datetime
import matplotlib.pyplot as plt

from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Bidirectional, Dropout, Flatten, GlobalAveragePooling1D, GlobalMaxPooling1D, Reshape, Multiply, GRU, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.initializers import GlorotUniform

# %% [markdown]
# # 處理一下資料

# %%
df[ (df['year_month_for_combine'] > '2024-03-31') ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5298 entries, 664436 to 669733
# Data columns (total 97 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   community_name                        5298 non-null   int64
#  1   main_building_ratio                   5298 non-null   float64
#  2   building_age                          5298 non-null   float64
#  3   total_area_ping                       5298 non-null   float64
#  4   total_floors                          5298 non-null   float64
#  5   target_floor                          5298 non-null   float64
#  6   transaction_floors                    5298 non-null   float64
#  7   bedrooms                              5298 non-null   float64
#  8   living_rooms                          5298 non-null   float64
#  9   bathrooms                             5298 non-null   float64
#  10  year_month_for_combine                5298 non-null   object
#  11  new_per_ping                          5298 non-null   float64
#  12  Public_Activity_Space_under_250_m     5298 non-null   float64
#  13  MRT_Exit_under_250_m                  5298 non-null   float64
#  14  Religious_Site_under_250_m            5298 non-null   float64
#  15  School_under_250_m                    5298 non-null   float64
#  16  Kindergarten_under_250_m              5298 non-null   float64
#  17  Convenience_Store_under_250_m         5298 non-null   float64
#  18  Bank_under_250_m                      5298 non-null   float64
#  19  Clinic_under_250_m                    5298 non-null   float64
#  20  Pharmacy_under_250_m                  5298 non-null   float64
#  21  acc_Public_Activity_Space_under_500m  5298 non-null   float64
#  22  acc_Public_Activity_Space_under_750m  5298 non-null   float64
#  23  acc_MRT_Exit_under_500m               5298 non-null   float64
#  24  acc_MRT_Exit_under_750m               5298 non-null   float64
#  25  acc_Religious_Site_under_500m         5298 non-null   float64
#  26  acc_Religious_Site_under_750m         5298 non-null   float64
#  27  acc_Shopping_Area_under_750m          5298 non-null   float64
#  28  acc_School_under_500m                 5298 non-null   float64
#  29  acc_School_under_750m                 5298 non-null   float64
#  30  acc_Hospital_under_500m               5298 non-null   float64
#  31  acc_Hospital_under_750m               5298 non-null   float64
#  32  acc_Gas_Station_under_750m            5298 non-null   float64
#  33  acc_Kindergarten_under_500m           5298 non-null   float64
#  34  acc_Kindergarten_under_750m           5298 non-null   float64
#  35  acc_Daycare_Center_under_500m         5298 non-null   float64
#  36  acc_Daycare_Center_under_750m         5298 non-null   float64
#  37  acc_Convenience_Store_under_500m      5298 non-null   float64
#  38  acc_Convenience_Store_under_750m      5298 non-null   float64
#  39  acc_Bank_under_500m                   5298 non-null   float64
#  40  acc_Bank_under_750m                   5298 non-null   float64
#  41  acc_Police_Station_under_750m         5298 non-null   float64
#  42  acc_Clinic_under_500m                 5298 non-null   float64
#  43  acc_Clinic_under_750m                 5298 non-null   float64
#  44  acc_Pharmacy_under_500m               5298 non-null   float64
#  45  acc_Pharmacy_under_750m               5298 non-null   float64
#  46  acc_Medical_Facility_under_750m       5298 non-null   float64
#  47  has_parking_space                     5298 non-null   int64
#  48  elevator_available                    5298 non-null   int64
#  49  property_type__公寓                     5298 non-null   int64
#  50  property_type__透天厝                    5298 non-null   int64
#  51  property_type__電梯大樓                   5298 non-null   int64
#  52  city__台北市                             5298 non-null   int64
#  53  city__新北市                             5298 non-null   int64
#  54  district__三峽區                         5298 non-null   int64
#  55  district__三芝區                         5298 non-null   int64
#  56  district__三重區                         5298 non-null   int64
#  57  district__中和區                         5298 non-null   int64
#  58  district__中山區                         5298 non-null   int64
#  59  district__中正區                         5298 non-null   int64
#  60  district__五股區                         5298 non-null   int64
#  61  district__信義區                         5298 non-null   int64
#  62  district__內湖區                         5298 non-null   int64
#  63  district__八里區                         5298 non-null   int64
#  64  district__北投區                         5298 non-null   int64
#  65  district__南港區                         5298 non-null   int64
#  66  district__土城區                         5298 non-null   int64
#  67  district__坪林區                         5298 non-null   int64
#  68  district__士林區                         5298 non-null   int64
#  69  district__大同區                         5298 non-null   int64
#  70  district__大安區                         5298 non-null   int64
#  71  district__平溪區                         5298 non-null   int64
#  72  district__文山區                         5298 non-null   int64
#  73  district__新店區                         5298 non-null   int64
#  74  district__新莊區                         5298 non-null   int64
#  75  district__松山區                         5298 non-null   int64
#  76  district__板橋區                         5298 non-null   int64
#  77  district__林口區                         5298 non-null   int64
#  78  district__樹林區                         5298 non-null   int64
#  79  district__永和區                         5298 non-null   int64
#  80  district__汐止區                         5298 non-null   int64
#  81  district__泰山區                         5298 non-null   int64
#  82  district__淡水區                         5298 non-null   int64
#  83  district__深坑區                         5298 non-null   int64
#  84  district__烏來區                         5298 non-null   int64
#  85  district__瑞芳區                         5298 non-null   int64
#  86  district__石碇區                         5298 non-null   int64
#  87  district__石門區                         5298 non-null   int64
#  88  district__萬華區                         5298 non-null   int64
#  89  district__萬里區                         5298 non-null   int64
#  90  district__蘆洲區                         5298 non-null   int64
#  91  district__貢寮區                         5298 non-null   int64
#  92  district__金山區                         5298 non-null   int64
#  93  district__雙溪區                         5298 non-null   int64
#  94  district__鶯歌區                         5298 non-null   int64
#  95  usage_category__住商用                   5298 non-null   int64
#  96  usage_category__住家用                   5298 non-null   int64
# dtypes: float64(45), int64(51), object(1)
# memory usage: 4.0+ MB

# %%
df.info(max_cols=134)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669734 entries, 0 to 669733
# Data columns (total 97 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   community_name                        669734 non-null  int64
#  1   main_building_ratio                   669734 non-null  float64
#  2   building_age                          669734 non-null  float64
#  3   total_area_ping                       669734 non-null  float64
#  4   total_floors                          669734 non-null  float64
#  5   target_floor                          669734 non-null  float64
#  6   transaction_floors                    669734 non-null  float64
#  7   bedrooms                              669734 non-null  float64
#  8   living_rooms                          669734 non-null  float64
#  9   bathrooms                             669734 non-null  float64
#  10  year_month_for_combine                669734 non-null  object
#  11  new_per_ping                          669734 non-null  float64
#  12  Public_Activity_Space_under_250_m     669734 non-null  float64
#  13  MRT_Exit_under_250_m                  669734 non-null  float64
#  14  Religious_Site_under_250_m            669734 non-null  float64
#  15  School_under_250_m                    669734 non-null  float64
#  16  Kindergarten_under_250_m              669734 non-null  float64
#  17  Convenience_Store_under_250_m         669734 non-null  float64
#  18  Bank_under_250_m                      669734 non-null  float64
#  19  Clinic_under_250_m                    669734 non-null  float64
#  20  Pharmacy_under_250_m                  669734 non-null  float64
#  21  acc_Public_Activity_Space_under_500m  669734 non-null  float64
#  22  acc_Public_Activity_Space_under_750m  669734 non-null  float64
#  23  acc_MRT_Exit_under_500m               669734 non-null  float64
#  24  acc_MRT_Exit_under_750m               669734 non-null  float64
#  25  acc_Religious_Site_under_500m         669734 non-null  float64
#  26  acc_Religious_Site_under_750m         669734 non-null  float64
#  27  acc_Shopping_Area_under_750m          669734 non-null  float64
#  28  acc_School_under_500m                 669734 non-null  float64
#  29  acc_School_under_750m                 669734 non-null  float64
#  30  acc_Hospital_under_500m               669734 non-null  float64
#  31  acc_Hospital_under_750m               669734 non-null  float64
#  32  acc_Gas_Station_under_750m            669734 non-null  float64
#  33  acc_Kindergarten_under_500m           669734 non-null  float64
#  34  acc_Kindergarten_under_750m           669734 non-null  float64
#  35  acc_Daycare_Center_under_500m         669734 non-null  float64
#  36  acc_Daycare_Center_under_750m         669734 non-null  float64
#  37  acc_Convenience_Store_under_500m      669734 non-null  float64
#  38  acc_Convenience_Store_under_750m      669734 non-null  float64
#  39  acc_Bank_under_500m                   669734 non-null  float64
#  40  acc_Bank_under_750m                   669734 non-null  float64
#  41  acc_Police_Station_under_750m         669734 non-null  float64
#  42  acc_Clinic_under_500m                 669734 non-null  float64
#  43  acc_Clinic_under_750m                 669734 non-null  float64
#  44  acc_Pharmacy_under_500m               669734 non-null  float64
#  45  acc_Pharmacy_under_750m               669734 non-null  float64
#  46  acc_Medical_Facility_under_750m       669734 non-null  float64
#  47  has_parking_space                     669734 non-null  int64
#  48  elevator_available                    669734 non-null  int64
#  49  property_type__公寓                     669734 non-null  int64
#  50  property_type__透天厝                    669734 non-null  int64
#  51  property_type__電梯大樓                   669734 non-null  int64
#  52  city__台北市                             669734 non-null  int64
#  53  city__新北市                             669734 non-null  int64
#  54  district__三峽區                         669734 non-null  int64
#  55  district__三芝區                         669734 non-null  int64
#  56  district__三重區                         669734 non-null  int64
#  57  district__中和區                         669734 non-null  int64
#  58  district__中山區                         669734 non-null  int64
#  59  district__中正區                         669734 non-null  int64
#  60  district__五股區                         669734 non-null  int64
#  61  district__信義區                         669734 non-null  int64
#  62  district__內湖區                         669734 non-null  int64
#  63  district__八里區                         669734 non-null  int64
#  64  district__北投區                         669734 non-null  int64
#  65  district__南港區                         669734 non-null  int64
#  66  district__土城區                         669734 non-null  int64
#  67  district__坪林區                         669734 non-null  int64
#  68  district__士林區                         669734 non-null  int64
#  69  district__大同區                         669734 non-null  int64
#  70  district__大安區                         669734 non-null  int64
#  71  district__平溪區                         669734 non-null  int64
#  72  district__文山區                         669734 non-null  int64
#  73  district__新店區                         669734 non-null  int64
#  74  district__新莊區                         669734 non-null  int64
#  75  district__松山區                         669734 non-null  int64
#  76  district__板橋區                         669734 non-null  int64
#  77  district__林口區                         669734 non-null  int64
#  78  district__樹林區                         669734 non-null  int64
#  79  district__永和區                         669734 non-null  int64
#  80  district__汐止區                         669734 non-null  int64
#  81  district__泰山區                         669734 non-null  int64
#  82  district__淡水區                         669734 non-null  int64
#  83  district__深坑區                         669734 non-null  int64
#  84  district__烏來區                         669734 non-null  int64
#  85  district__瑞芳區                         669734 non-null  int64
#  86  district__石碇區                         669734 non-null  int64
#  87  district__石門區                         669734 non-null  int64
#  88  district__萬華區                         669734 non-null  int64
#  89  district__萬里區                         669734 non-null  int64
#  90  district__蘆洲區                         669734 non-null  int64
#  91  district__貢寮區                         669734 non-null  int64
#  92  district__金山區                         669734 non-null  int64
#  93  district__雙溪區                         669734 non-null  int64
#  94  district__鶯歌區                         669734 non-null  int64
#  95  usage_category__住商用                   669734 non-null  int64
#  96  usage_category__住家用                   669734 non-null  int64
# dtypes: float64(45), int64(51), object(1)
# memory usage: 495.6+ MB

# %% [markdown]
# ## CBAM layer (1D version)

# %%
class CBAMLayer(tf.keras.Model):
    def __init__(self, channel, reduction=16, spatial_kernel=7):   # 作者預設: reduction=16, spatial_kernel=7(這是論文設定值，可能有神麼意義?)
        super(CBAMLayer, self).__init__()
        self.channel = channel

        # Channel attention
        self.max_pool = GlobalMaxPooling1D()
        self.avg_pool = GlobalAveragePooling1D()

        self.mlp = tf.keras.Sequential([
            Dense(channel // reduction, use_bias=False), # 利用channel除以reduction，壓縮到縮到一個維度較低的空間
            tf.keras.layers.Activation('relu'),
            Dense(channel, use_bias=False)               # 然後再過一個回到channel數量的維度
        ])

        # Spatial attention
        self.conv = Conv1D(1, (spatial_kernel), padding='same', use_bias=False)
        self.sigmoid = tf.keras.layers.Activation('sigmoid')

    # 這應該是繼承來overwrite(或是實作(本來可能根本沒寫(抽象方法的概念)))的方法，定義好之後因為keras每一層會自動訓練，所以裏頭也就是會去呼叫這個叫做call()的方法，所以這個名子不能去改
    def call(self, x):
        max_out = self.mlp(Reshape((1, self.channel))(self.max_pool(x))) # MLP轉換 # x是輸入的張量 # Reshape將self.max_pool(x)出來的值的形狀改成(1, self.channel)，基本上在這裡self.max_pool(x)的形狀應該會是(32,)，因為總共有32個filter，這樣做是因為TensorFlow Dense層要求的input shape 為 (#batch_size(反正就是樣本數), #input_dimension)，只有一筆所以就給1，然後是32個特徵(維)，寫法蠻神奇的要注意一下
        avg_out = self.mlp(Reshape((1, self.channel))(self.avg_pool(x))) # MLP轉換
        channel_out = self.sigmoid(max_out + avg_out)   # 經MLP轉換後的maxpooling跟averagepooling相加後，再過一個sigmoid
        x = Multiply()([channel_out, x])

        max_out = tf.reduce_max(x, axis=2, keepdims=True)
        avg_out = tf.reduce_mean(x, axis=2, keepdims=True)
        spatial_out = self.sigmoid(self.conv(tf.concat([max_out, avg_out], axis=2)))
        x = Multiply()([spatial_out, x])
        return x

# %% [markdown]
# ## time series window create

# %%
only_eco_file_path = '/content/my_drive/MyDrive/BDSE34期末報告_房價/all_data/final_eco_df_to_11306_fillna_v2.csv'
only_eco_df = pd.read_csv(only_eco_file_path, encoding='utf-8')

# %%
only_eco_df.drop('year_month_for_combine', axis=1, inplace=True)

# %%
# to create eco lag shift data
def create_windows_of_each_eco_index(only_eco_df: pd.DataFrame, windows_size):
  vars_shift_df = only_eco_df.iloc[:,0:2]
  vars_shift_df.columns = ['date', 'target_index_house_index_xyi_all_tp']
  col_vars = only_eco_df.columns.drop('date')
  for lag in range(1, windows_size+1, 1):
    for eco_name in col_vars:
        var = eco_name
        vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
  vars_shift_df.fillna(method='bfill', inplace=True)
  return vars_shift_df

# %%
# 經濟指數有23個 (window_size=n, eco_index=23)
window_df_5 = create_windows_of_each_eco_index(only_eco_df, 5) # 目前做12個月
# Out:
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)

# %%
window_df_5.info(max_cols=117)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 117 columns):
#  #    Column                               Non-Null Count  Dtype
# ---   ------                               --------------  -----
#  0    date                                 162 non-null    object
#  1    target_index_house_index_xyi_all_tp  162 non-null    float64
#  2    house_index_xyi_all_tp_lag_1         162 non-null    float64
#  3    house_index_xyi_tp_lag_1             162 non-null    float64
#  4    house_index_xyi_new_tp_lag_1         162 non-null    float64
#  5    EB18_lag_1                           162 non-null    float64
#  6    EB21_lag_1                           162 non-null    float64
#  7    MC31_lag_1                           162 non-null    float64
#  8    MC31G_lag_1                          162 non-null    float64
#  9    MC36_lag_1                           162 non-null    float64
#  10   NA0101_lag_1                         162 non-null    float64
#  11   NA1005_lag_1                         162 non-null    float64
#  12   NB0101_lag_1                         162 non-null    float64
#  13   NC0117_lag_1                         162 non-null    float64
#  14   NC0118_lag_1                         162 non-null    float64
#  15   NE0206_lag_1                         162 non-null    float64
#  16   PA0120_lag_1                         162 non-null    float64
#  17   PA1205_lag_1                         162 non-null    float64
#  18   PE0503_lag_1                         162 non-null    float64
#  19   TSE收盤_lag_1                          162 non-null    float64
#  20   水泥(TSE11)收盤_lag_1                    162 non-null    float64
#  21   建材營造(TSE25)收盤_lag_1                  162 non-null    float64
#  22   航運業(TSE26)收盤_lag_1                   162 non-null    float64
#  23   鋼鐵(TSE20)收盤_lag_1                    162 non-null    float64
#  24   預拌混凝土3000磅台北_lag_1                   162 non-null    float64
#  25   house_index_xyi_all_tp_lag_2         162 non-null    float64
#  26   house_index_xyi_tp_lag_2             162 non-null    float64
#  27   house_index_xyi_new_tp_lag_2         162 non-null    float64
#  28   EB18_lag_2                           162 non-null    float64
#  29   EB21_lag_2                           162 non-null    float64
#  30   MC31_lag_2                           162 non-null    float64
#  31   MC31G_lag_2                          162 non-null    float64
#  32   MC36_lag_2                           162 non-null    float64
#  33   NA0101_lag_2                         162 non-null    float64
#  34   NA1005_lag_2                         162 non-null    float64
#  35   NB0101_lag_2                         162 non-null    float64
#  36   NC0117_lag_2                         162 non-null    float64
#  37   NC0118_lag_2                         162 non-null    float64
#  38   NE0206_lag_2                         162 non-null    float64
#  39   PA0120_lag_2                         162 non-null    float64
#  40   PA1205_lag_2                         162 non-null    float64
#  41   PE0503_lag_2                         162 non-null    float64
#  42   TSE收盤_lag_2                          162 non-null    float64
#  43   水泥(TSE11)收盤_lag_2                    162 non-null    float64
#  44   建材營造(TSE25)收盤_lag_2                  162 non-null    float64
#  45   航運業(TSE26)收盤_lag_2                   162 non-null    float64
#  46   鋼鐵(TSE20)收盤_lag_2                    162 non-null    float64
#  47   預拌混凝土3000磅台北_lag_2                   162 non-null    float64
#  48   house_index_xyi_all_tp_lag_3         162 non-null    float64
#  49   house_index_xyi_tp_lag_3             162 non-null    float64
#  50   house_index_xyi_new_tp_lag_3         162 non-null    float64
#  51   EB18_lag_3                           162 non-null    float64
#  52   EB21_lag_3                           162 non-null    float64
#  53   MC31_lag_3                           162 non-null    float64
#  54   MC31G_lag_3                          162 non-null    float64
#  55   MC36_lag_3                           162 non-null    float64
#  56   NA0101_lag_3                         162 non-null    float64
#  57   NA1005_lag_3                         162 non-null    float64
#  58   NB0101_lag_3                         162 non-null    float64
#  59   NC0117_lag_3                         162 non-null    float64
#  60   NC0118_lag_3                         162 non-null    float64
#  61   NE0206_lag_3                         162 non-null    float64
#  62   PA0120_lag_3                         162 non-null    float64
#  63   PA1205_lag_3                         162 non-null    float64
#  64   PE0503_lag_3                         162 non-null    float64
#  65   TSE收盤_lag_3                          162 non-null    float64
#  66   水泥(TSE11)收盤_lag_3                    162 non-null    float64
#  67   建材營造(TSE25)收盤_lag_3                  162 non-null    float64
#  68   航運業(TSE26)收盤_lag_3                   162 non-null    float64
#  69   鋼鐵(TSE20)收盤_lag_3                    162 non-null    float64
#  70   預拌混凝土3000磅台北_lag_3                   162 non-null    float64
#  71   house_index_xyi_all_tp_lag_4         162 non-null    float64
#  72   house_index_xyi_tp_lag_4             162 non-null    float64
#  73   house_index_xyi_new_tp_lag_4         162 non-null    float64
#  74   EB18_lag_4                           162 non-null    float64
#  75   EB21_lag_4                           162 non-null    float64
#  76   MC31_lag_4                           162 non-null    float64
#  77   MC31G_lag_4                          162 non-null    float64
#  78   MC36_lag_4                           162 non-null    float64
#  79   NA0101_lag_4                         162 non-null    float64
#  80   NA1005_lag_4                         162 non-null    float64
#  81   NB0101_lag_4                         162 non-null    float64
#  82   NC0117_lag_4                         162 non-null    float64
#  83   NC0118_lag_4                         162 non-null    float64
#  84   NE0206_lag_4                         162 non-null    float64
#  85   PA0120_lag_4                         162 non-null    float64
#  86   PA1205_lag_4                         162 non-null    float64
#  87   PE0503_lag_4                         162 non-null    float64
#  88   TSE收盤_lag_4                          162 non-null    float64
#  89   水泥(TSE11)收盤_lag_4                    162 non-null    float64
#  90   建材營造(TSE25)收盤_lag_4                  162 non-null    float64
#  91   航運業(TSE26)收盤_lag_4                   162 non-null    float64
#  92   鋼鐵(TSE20)收盤_lag_4                    162 non-null    float64
#  93   預拌混凝土3000磅台北_lag_4                   162 non-null    float64
#  94   house_index_xyi_all_tp_lag_5         162 non-null    float64
#  95   house_index_xyi_tp_lag_5             162 non-null    float64
#  96   house_index_xyi_new_tp_lag_5         162 non-null    float64
#  97   EB18_lag_5                           162 non-null    float64
#  98   EB21_lag_5                           162 non-null    float64
#  99   MC31_lag_5                           162 non-null    float64
#  100  MC31G_lag_5                          162 non-null    float64
#  101  MC36_lag_5                           162 non-null    float64
#  102  NA0101_lag_5                         162 non-null    float64
#  103  NA1005_lag_5                         162 non-null    float64
#  104  NB0101_lag_5                         162 non-null    float64
#  105  NC0117_lag_5                         162 non-null    float64
#  106  NC0118_lag_5                         162 non-null    float64
#  107  NE0206_lag_5                         162 non-null    float64
#  108  PA0120_lag_5                         162 non-null    float64
#  109  PA1205_lag_5                         162 non-null    float64
#  110  PE0503_lag_5                         162 non-null    float64
#  111  TSE收盤_lag_5                          162 non-null    float64
#  112  水泥(TSE11)收盤_lag_5                    162 non-null    float64
#  113  建材營造(TSE25)收盤_lag_5                  162 non-null    float64
#  114  航運業(TSE26)收盤_lag_5                   162 non-null    float64
#  115  鋼鐵(TSE20)收盤_lag_5                    162 non-null    float64
#  116  預拌混凝土3000磅台北_lag_5                   162 non-null    float64
# dtypes: float64(116), object(1)
# memory usage: 148.2+ KB

# %%
window_df_5['date'] = pd.to_datetime(window_df_5['date'])
window_df_5['year_month_for_combine'] = window_df_5['date'].dt.to_period('M')
df['year_month_for_combine'] = pd.to_datetime(df['year_month_for_combine'])
df['year_month_for_combine'] = df['year_month_for_combine'].dt.to_period('M')
# Out:
# <ipython-input-12-efd557384d7f>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   window_df_5['year_month_for_combine'] = window_df_5['date'].dt.to_period('M')

# %%
nn_final_df = df.merge(window_df_5, left_on='year_month_for_combine', right_on='year_month_for_combine', how='inner')

# %%
nn_final_df.drop(['date'], axis=1, inplace=True)

# %% [markdown]
# ## 分X, y (要先切分test, train, validation，再來分time, non_time)

# %%
nn_final_df.info(max_cols=213)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669734 entries, 0 to 669733
# Data columns (total 213 columns):
#  #    Column                                Non-Null Count   Dtype
# ---   ------                                --------------   -----
#  0    community_name                        669734 non-null  int64
#  1    main_building_ratio                   669734 non-null  float64
#  2    building_age                          669734 non-null  float64
#  3    total_area_ping                       669734 non-null  float64
#  4    total_floors                          669734 non-null  float64
#  5    target_floor                          669734 non-null  float64
#  6    transaction_floors                    669734 non-null  float64
#  7    bedrooms                              669734 non-null  float64
#  8    living_rooms                          669734 non-null  float64
#  9    bathrooms                             669734 non-null  float64
#  10   year_month_for_combine                669734 non-null  period[M]
#  11   new_per_ping                          669734 non-null  float64
#  12   Public_Activity_Space_under_250_m     669734 non-null  float64
#  13   MRT_Exit_under_250_m                  669734 non-null  float64
#  14   Religious_Site_under_250_m            669734 non-null  float64
#  15   School_under_250_m                    669734 non-null  float64
#  16   Kindergarten_under_250_m              669734 non-null  float64
#  17   Convenience_Store_under_250_m         669734 non-null  float64
#  18   Bank_under_250_m                      669734 non-null  float64
#  19   Clinic_under_250_m                    669734 non-null  float64
#  20   Pharmacy_under_250_m                  669734 non-null  float64
#  21   acc_Public_Activity_Space_under_500m  669734 non-null  float64
#  22   acc_Public_Activity_Space_under_750m  669734 non-null  float64
#  23   acc_MRT_Exit_under_500m               669734 non-null  float64
#  24   acc_MRT_Exit_under_750m               669734 non-null  float64
#  25   acc_Religious_Site_under_500m         669734 non-null  float64
#  26   acc_Religious_Site_under_750m         669734 non-null  float64
#  27   acc_Shopping_Area_under_750m          669734 non-null  float64
#  28   acc_School_under_500m                 669734 non-null  float64
#  29   acc_School_under_750m                 669734 non-null  float64
#  30   acc_Hospital_under_500m               669734 non-null  float64
#  31   acc_Hospital_under_750m               669734 non-null  float64
#  32   acc_Gas_Station_under_750m            669734 non-null  float64
#  33   acc_Kindergarten_under_500m           669734 non-null  float64
#  34   acc_Kindergarten_under_750m           669734 non-null  float64
#  35   acc_Daycare_Center_under_500m         669734 non-null  float64
#  36   acc_Daycare_Center_under_750m         669734 non-null  float64
#  37   acc_Convenience_Store_under_500m      669734 non-null  float64
#  38   acc_Convenience_Store_under_750m      669734 non-null  float64
#  39   acc_Bank_under_500m                   669734 non-null  float64
#  40   acc_Bank_under_750m                   669734 non-null  float64
#  41   acc_Police_Station_under_750m         669734 non-null  float64
#  42   acc_Clinic_under_500m                 669734 non-null  float64
#  43   acc_Clinic_under_750m                 669734 non-null  float64
#  44   acc_Pharmacy_under_500m               669734 non-null  float64
#  45   acc_Pharmacy_under_750m               669734 non-null  float64
#  46   acc_Medical_Facility_under_750m       669734 non-null  float64
#  47   has_parking_space                     669734 non-null  int64
#  48   elevator_available                    669734 non-null  int64
#  49   property_type__公寓                     669734 non-null  int64
#  50   property_type__透天厝                    669734 non-null  int64
#  51   property_type__電梯大樓                   669734 non-null  int64
#  52   city__台北市                             669734 non-null  int64
#  53   city__新北市                             669734 non-null  int64
#  54   district__三峽區                         669734 non-null  int64
#  55   district__三芝區                         669734 non-null  int64
#  56   district__三重區                         669734 non-null  int64
#  57   district__中和區                         669734 non-null  int64
#  58   district__中山區                         669734 non-null  int64
#  59   district__中正區                         669734 non-null  int64
#  60   district__五股區                         669734 non-null  int64
#  61   district__信義區                         669734 non-null  int64
#  62   district__內湖區                         669734 non-null  int64
#  63   district__八里區                         669734 non-null  int64
#  64   district__北投區                         669734 non-null  int64
#  65   district__南港區                         669734 non-null  int64
#  66   district__土城區                         669734 non-null  int64
#  67   district__坪林區                         669734 non-null  int64
#  68   district__士林區                         669734 non-null  int64
#  69   district__大同區                         669734 non-null  int64
#  70   district__大安區                         669734 non-null  int64
#  71   district__平溪區                         669734 non-null  int64
#  72   district__文山區                         669734 non-null  int64
#  73   district__新店區                         669734 non-null  int64
#  74   district__新莊區                         669734 non-null  int64
#  75   district__松山區                         669734 non-null  int64
#  76   district__板橋區                         669734 non-null  int64
#  77   district__林口區                         669734 non-null  int64
#  78   district__樹林區                         669734 non-null  int64
#  79   district__永和區                         669734 non-null  int64
#  80   district__汐止區                         669734 non-null  int64
#  81   district__泰山區                         669734 non-null  int64
#  82   district__淡水區                         669734 non-null  int64
#  83   district__深坑區                         669734 non-null  int64
#  84   district__烏來區                         669734 non-null  int64
#  85   district__瑞芳區                         669734 non-null  int64
#  86   district__石碇區                         669734 non-null  int64
#  87   district__石門區                         669734 non-null  int64
#  88   district__萬華區                         669734 non-null  int64
#  89   district__萬里區                         669734 non-null  int64
#  90   district__蘆洲區                         669734 non-null  int64
#  91   district__貢寮區                         669734 non-null  int64
#  92   district__金山區                         669734 non-null  int64
#  93   district__雙溪區                         669734 non-null  int64
#  94   district__鶯歌區                         669734 non-null  int64
#  95   usage_category__住商用                   669734 non-null  int64
#  96   usage_category__住家用                   669734 non-null  int64
#  97   target_index_house_index_xyi_all_tp   669734 non-null  float64
#  98   house_index_xyi_all_tp_lag_1          669734 non-null  float64
#  99   house_index_xyi_tp_lag_1              669734 non-null  float64
#  100  house_index_xyi_new_tp_lag_1          669734 non-null  float64
#  101  EB18_lag_1                            669734 non-null  float64
#  102  EB21_lag_1                            669734 non-null  float64
#  103  MC31_lag_1                            669734 non-null  float64
#  104  MC31G_lag_1                           669734 non-null  float64
#  105  MC36_lag_1                            669734 non-null  float64
#  106  NA0101_lag_1                          669734 non-null  float64
#  107  NA1005_lag_1                          669734 non-null  float64
#  108  NB0101_lag_1                          669734 non-null  float64
#  109  NC0117_lag_1                          669734 non-null  float64
#  110  NC0118_lag_1                          669734 non-null  float64
#  111  NE0206_lag_1                          669734 non-null  float64
#  112  PA0120_lag_1                          669734 non-null  float64
#  113  PA1205_lag_1                          669734 non-null  float64
#  114  PE0503_lag_1                          669734 non-null  float64
#  115  TSE收盤_lag_1                           669734 non-null  float64
#  116  水泥(TSE11)收盤_lag_1                     669734 non-null  float64
#  117  建材營造(TSE25)收盤_lag_1                   669734 non-null  float64
#  118  航運業(TSE26)收盤_lag_1                    669734 non-null  float64
#  119  鋼鐵(TSE20)收盤_lag_1                     669734 non-null  float64
#  120  預拌混凝土3000磅台北_lag_1                    669734 non-null  float64
#  121  house_index_xyi_all_tp_lag_2          669734 non-null  float64
#  122  house_index_xyi_tp_lag_2              669734 non-null  float64
#  123  house_index_xyi_new_tp_lag_2          669734 non-null  float64
#  124  EB18_lag_2                            669734 non-null  float64
#  125  EB21_lag_2                            669734 non-null  float64
#  126  MC31_lag_2                            669734 non-null  float64
#  127  MC31G_lag_2                           669734 non-null  float64
#  128  MC36_lag_2                            669734 non-null  float64
#  129  NA0101_lag_2                          669734 non-null  float64
#  130  NA1005_lag_2                          669734 non-null  float64
#  131  NB0101_lag_2                          669734 non-null  float64
#  132  NC0117_lag_2                          669734 non-null  float64
#  133  NC0118_lag_2                          669734 non-null  float64
#  134  NE0206_lag_2                          669734 non-null  float64
#  135  PA0120_lag_2                          669734 non-null  float64
#  136  PA1205_lag_2                          669734 non-null  float64
#  137  PE0503_lag_2                          669734 non-null  float64
#  138  TSE收盤_lag_2                           669734 non-null  float64
#  139  水泥(TSE11)收盤_lag_2                     669734 non-null  float64
#  140  建材營造(TSE25)收盤_lag_2                   669734 non-null  float64
#  141  航運業(TSE26)收盤_lag_2                    669734 non-null  float64
#  142  鋼鐵(TSE20)收盤_lag_2                     669734 non-null  float64
#  143  預拌混凝土3000磅台北_lag_2                    669734 non-null  float64
#  144  house_index_xyi_all_tp_lag_3          669734 non-null  float64
#  145  house_index_xyi_tp_lag_3              669734 non-null  float64
#  146  house_index_xyi_new_tp_lag_3          669734 non-null  float64
#  147  EB18_lag_3                            669734 non-null  float64
#  148  EB21_lag_3                            669734 non-null  float64
#  149  MC31_lag_3                            669734 non-null  float64
#  150  MC31G_lag_3                           669734 non-null  float64
#  151  MC36_lag_3                            669734 non-null  float64
#  152  NA0101_lag_3                          669734 non-null  float64
#  153  NA1005_lag_3                          669734 non-null  float64
#  154  NB0101_lag_3                          669734 non-null  float64
#  155  NC0117_lag_3                          669734 non-null  float64
#  156  NC0118_lag_3                          669734 non-null  float64
#  157  NE0206_lag_3                          669734 non-null  float64
#  158  PA0120_lag_3                          669734 non-null  float64
#  159  PA1205_lag_3                          669734 non-null  float64
#  160  PE0503_lag_3                          669734 non-null  float64
#  161  TSE收盤_lag_3                           669734 non-null  float64
#  162  水泥(TSE11)收盤_lag_3                     669734 non-null  float64
#  163  建材營造(TSE25)收盤_lag_3                   669734 non-null  float64
#  164  航運業(TSE26)收盤_lag_3                    669734 non-null  float64
#  165  鋼鐵(TSE20)收盤_lag_3                     669734 non-null  float64
#  166  預拌混凝土3000磅台北_lag_3                    669734 non-null  float64
#  167  house_index_xyi_all_tp_lag_4          669734 non-null  float64
#  168  house_index_xyi_tp_lag_4              669734 non-null  float64
#  169  house_index_xyi_new_tp_lag_4          669734 non-null  float64
#  170  EB18_lag_4                            669734 non-null  float64
#  171  EB21_lag_4                            669734 non-null  float64
#  172  MC31_lag_4                            669734 non-null  float64
#  173  MC31G_lag_4                           669734 non-null  float64
#  174  MC36_lag_4                            669734 non-null  float64
#  175  NA0101_lag_4                          669734 non-null  float64
#  176  NA1005_lag_4                          669734 non-null  float64
#  177  NB0101_lag_4                          669734 non-null  float64
#  178  NC0117_lag_4                          669734 non-null  float64
#  179  NC0118_lag_4                          669734 non-null  float64
#  180  NE0206_lag_4                          669734 non-null  float64
#  181  PA0120_lag_4                          669734 non-null  float64
#  182  PA1205_lag_4                          669734 non-null  float64
#  183  PE0503_lag_4                          669734 non-null  float64
#  184  TSE收盤_lag_4                           669734 non-null  float64
#  185  水泥(TSE11)收盤_lag_4                     669734 non-null  float64
#  186  建材營造(TSE25)收盤_lag_4                   669734 non-null  float64
#  187  航運業(TSE26)收盤_lag_4                    669734 non-null  float64
#  188  鋼鐵(TSE20)收盤_lag_4                     669734 non-null  float64
#  189  預拌混凝土3000磅台北_lag_4                    669734 non-null  float64
#  190  house_index_xyi_all_tp_lag_5          669734 non-null  float64
#  191  house_index_xyi_tp_lag_5              669734 non-null  float64
#  192  house_index_xyi_new_tp_lag_5          669734 non-null  float64
#  193  EB18_lag_5                            669734 non-null  float64
#  194  EB21_lag_5                            669734 non-null  float64
#  195  MC31_lag_5                            669734 non-null  float64
#  196  MC31G_lag_5                           669734 non-null  float64
#  197  MC36_lag_5                            669734 non-null  float64
#  198  NA0101_lag_5                          669734 non-null  float64
#  199  NA1005_lag_5                          669734 non-null  float64
#  200  NB0101_lag_5                          669734 non-null  float64
#  201  NC0117_lag_5                          669734 non-null  float64
#  202  NC0118_lag_5                          669734 non-null  float64
#  203  NE0206_lag_5                          669734 non-null  float64
#  204  PA0120_lag_5                          669734 non-null  float64
#  205  PA1205_lag_5                          669734 non-null  float64
#  206  PE0503_lag_5                          669734 non-null  float64
#  207  TSE收盤_lag_5                           669734 non-null  float64
#  208  水泥(TSE11)收盤_lag_5                     669734 non-null  float64
#  209  建材營造(TSE25)收盤_lag_5                   669734 non-null  float64
#  210  航運業(TSE26)收盤_lag_5                    669734 non-null  float64
#  211  鋼鐵(TSE20)收盤_lag_5                     669734 non-null  float64
#  212  預拌混凝土3000磅台北_lag_5                    669734 non-null  float64
# dtypes: float64(161), int64(51), period[M](1)
# memory usage: 1.1 GB

# %%
df = nn_final_df.copy()

# %%
main_df_col_list = df.columns

# %%
df.info(max_cols=213)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669734 entries, 0 to 669733
# Data columns (total 213 columns):
#  #    Column                                Non-Null Count   Dtype
# ---   ------                                --------------   -----
#  0    community_name                        669734 non-null  int64
#  1    main_building_ratio                   669734 non-null  float64
#  2    building_age                          669734 non-null  float64
#  3    total_area_ping                       669734 non-null  float64
#  4    total_floors                          669734 non-null  float64
#  5    target_floor                          669734 non-null  float64
#  6    transaction_floors                    669734 non-null  float64
#  7    bedrooms                              669734 non-null  float64
#  8    living_rooms                          669734 non-null  float64
#  9    bathrooms                             669734 non-null  float64
#  10   year_month_for_combine                669734 non-null  period[M]
#  11   new_per_ping                          669734 non-null  float64
#  12   Public_Activity_Space_under_250_m     669734 non-null  float64
#  13   MRT_Exit_under_250_m                  669734 non-null  float64
#  14   Religious_Site_under_250_m            669734 non-null  float64
#  15   School_under_250_m                    669734 non-null  float64
#  16   Kindergarten_under_250_m              669734 non-null  float64
#  17   Convenience_Store_under_250_m         669734 non-null  float64
#  18   Bank_under_250_m                      669734 non-null  float64
#  19   Clinic_under_250_m                    669734 non-null  float64
#  20   Pharmacy_under_250_m                  669734 non-null  float64
#  21   acc_Public_Activity_Space_under_500m  669734 non-null  float64
#  22   acc_Public_Activity_Space_under_750m  669734 non-null  float64
#  23   acc_MRT_Exit_under_500m               669734 non-null  float64
#  24   acc_MRT_Exit_under_750m               669734 non-null  float64
#  25   acc_Religious_Site_under_500m         669734 non-null  float64
#  26   acc_Religious_Site_under_750m         669734 non-null  float64
#  27   acc_Shopping_Area_under_750m          669734 non-null  float64
#  28   acc_School_under_500m                 669734 non-null  float64
#  29   acc_School_under_750m                 669734 non-null  float64
#  30   acc_Hospital_under_500m               669734 non-null  float64
#  31   acc_Hospital_under_750m               669734 non-null  float64
#  32   acc_Gas_Station_under_750m            669734 non-null  float64
#  33   acc_Kindergarten_under_500m           669734 non-null  float64
#  34   acc_Kindergarten_under_750m           669734 non-null  float64
#  35   acc_Daycare_Center_under_500m         669734 non-null  float64
#  36   acc_Daycare_Center_under_750m         669734 non-null  float64
#  37   acc_Convenience_Store_under_500m      669734 non-null  float64
#  38   acc_Convenience_Store_under_750m      669734 non-null  float64
#  39   acc_Bank_under_500m                   669734 non-null  float64
#  40   acc_Bank_under_750m                   669734 non-null  float64
#  41   acc_Police_Station_under_750m         669734 non-null  float64
#  42   acc_Clinic_under_500m                 669734 non-null  float64
#  43   acc_Clinic_under_750m                 669734 non-null  float64
#  44   acc_Pharmacy_under_500m               669734 non-null  float64
#  45   acc_Pharmacy_under_750m               669734 non-null  float64
#  46   acc_Medical_Facility_under_750m       669734 non-null  float64
#  47   has_parking_space                     669734 non-null  int64
#  48   elevator_available                    669734 non-null  int64
#  49   property_type__公寓                     669734 non-null  int64
#  50   property_type__透天厝                    669734 non-null  int64
#  51   property_type__電梯大樓                   669734 non-null  int64
#  52   city__台北市                             669734 non-null  int64
#  53   city__新北市                             669734 non-null  int64
#  54   district__三峽區                         669734 non-null  int64
#  55   district__三芝區                         669734 non-null  int64
#  56   district__三重區                         669734 non-null  int64
#  57   district__中和區                         669734 non-null  int64
#  58   district__中山區                         669734 non-null  int64
#  59   district__中正區                         669734 non-null  int64
#  60   district__五股區                         669734 non-null  int64
#  61   district__信義區                         669734 non-null  int64
#  62   district__內湖區                         669734 non-null  int64
#  63   district__八里區                         669734 non-null  int64
#  64   district__北投區                         669734 non-null  int64
#  65   district__南港區                         669734 non-null  int64
#  66   district__土城區                         669734 non-null  int64
#  67   district__坪林區                         669734 non-null  int64
#  68   district__士林區                         669734 non-null  int64
#  69   district__大同區                         669734 non-null  int64
#  70   district__大安區                         669734 non-null  int64
#  71   district__平溪區                         669734 non-null  int64
#  72   district__文山區                         669734 non-null  int64
#  73   district__新店區                         669734 non-null  int64
#  74   district__新莊區                         669734 non-null  int64
#  75   district__松山區                         669734 non-null  int64
#  76   district__板橋區                         669734 non-null  int64
#  77   district__林口區                         669734 non-null  int64
#  78   district__樹林區                         669734 non-null  int64
#  79   district__永和區                         669734 non-null  int64
#  80   district__汐止區                         669734 non-null  int64
#  81   district__泰山區                         669734 non-null  int64
#  82   district__淡水區                         669734 non-null  int64
#  83   district__深坑區                         669734 non-null  int64
#  84   district__烏來區                         669734 non-null  int64
#  85   district__瑞芳區                         669734 non-null  int64
#  86   district__石碇區                         669734 non-null  int64
#  87   district__石門區                         669734 non-null  int64
#  88   district__萬華區                         669734 non-null  int64
#  89   district__萬里區                         669734 non-null  int64
#  90   district__蘆洲區                         669734 non-null  int64
#  91   district__貢寮區                         669734 non-null  int64
#  92   district__金山區                         669734 non-null  int64
#  93   district__雙溪區                         669734 non-null  int64
#  94   district__鶯歌區                         669734 non-null  int64
#  95   usage_category__住商用                   669734 non-null  int64
#  96   usage_category__住家用                   669734 non-null  int64
#  97   target_index_house_index_xyi_all_tp   669734 non-null  float64
#  98   house_index_xyi_all_tp_lag_1          669734 non-null  float64
#  99   house_index_xyi_tp_lag_1              669734 non-null  float64
#  100  house_index_xyi_new_tp_lag_1          669734 non-null  float64
#  101  EB18_lag_1                            669734 non-null  float64
#  102  EB21_lag_1                            669734 non-null  float64
#  103  MC31_lag_1                            669734 non-null  float64
#  104  MC31G_lag_1                           669734 non-null  float64
#  105  MC36_lag_1                            669734 non-null  float64
#  106  NA0101_lag_1                          669734 non-null  float64
#  107  NA1005_lag_1                          669734 non-null  float64
#  108  NB0101_lag_1                          669734 non-null  float64
#  109  NC0117_lag_1                          669734 non-null  float64
#  110  NC0118_lag_1                          669734 non-null  float64
#  111  NE0206_lag_1                          669734 non-null  float64
#  112  PA0120_lag_1                          669734 non-null  float64
#  113  PA1205_lag_1                          669734 non-null  float64
#  114  PE0503_lag_1                          669734 non-null  float64
#  115  TSE收盤_lag_1                           669734 non-null  float64
#  116  水泥(TSE11)收盤_lag_1                     669734 non-null  float64
#  117  建材營造(TSE25)收盤_lag_1                   669734 non-null  float64
#  118  航運業(TSE26)收盤_lag_1                    669734 non-null  float64
#  119  鋼鐵(TSE20)收盤_lag_1                     669734 non-null  float64
#  120  預拌混凝土3000磅台北_lag_1                    669734 non-null  float64
#  121  house_index_xyi_all_tp_lag_2          669734 non-null  float64
#  122  house_index_xyi_tp_lag_2              669734 non-null  float64
#  123  house_index_xyi_new_tp_lag_2          669734 non-null  float64
#  124  EB18_lag_2                            669734 non-null  float64
#  125  EB21_lag_2                            669734 non-null  float64
#  126  MC31_lag_2                            669734 non-null  float64
#  127  MC31G_lag_2                           669734 non-null  float64
#  128  MC36_lag_2                            669734 non-null  float64
#  129  NA0101_lag_2                          669734 non-null  float64
#  130  NA1005_lag_2                          669734 non-null  float64
#  131  NB0101_lag_2                          669734 non-null  float64
#  132  NC0117_lag_2                          669734 non-null  float64
#  133  NC0118_lag_2                          669734 non-null  float64
#  134  NE0206_lag_2                          669734 non-null  float64
#  135  PA0120_lag_2                          669734 non-null  float64
#  136  PA1205_lag_2                          669734 non-null  float64
#  137  PE0503_lag_2                          669734 non-null  float64
#  138  TSE收盤_lag_2                           669734 non-null  float64
#  139  水泥(TSE11)收盤_lag_2                     669734 non-null  float64
#  140  建材營造(TSE25)收盤_lag_2                   669734 non-null  float64
#  141  航運業(TSE26)收盤_lag_2                    669734 non-null  float64
#  142  鋼鐵(TSE20)收盤_lag_2                     669734 non-null  float64
#  143  預拌混凝土3000磅台北_lag_2                    669734 non-null  float64
#  144  house_index_xyi_all_tp_lag_3          669734 non-null  float64
#  145  house_index_xyi_tp_lag_3              669734 non-null  float64
#  146  house_index_xyi_new_tp_lag_3          669734 non-null  float64
#  147  EB18_lag_3                            669734 non-null  float64
#  148  EB21_lag_3                            669734 non-null  float64
#  149  MC31_lag_3                            669734 non-null  float64
#  150  MC31G_lag_3                           669734 non-null  float64
#  151  MC36_lag_3                            669734 non-null  float64
#  152  NA0101_lag_3                          669734 non-null  float64
#  153  NA1005_lag_3                          669734 non-null  float64
#  154  NB0101_lag_3                          669734 non-null  float64
#  155  NC0117_lag_3                          669734 non-null  float64
#  156  NC0118_lag_3                          669734 non-null  float64
#  157  NE0206_lag_3                          669734 non-null  float64
#  158  PA0120_lag_3                          669734 non-null  float64
#  159  PA1205_lag_3                          669734 non-null  float64
#  160  PE0503_lag_3                          669734 non-null  float64
#  161  TSE收盤_lag_3                           669734 non-null  float64
#  162  水泥(TSE11)收盤_lag_3                     669734 non-null  float64
#  163  建材營造(TSE25)收盤_lag_3                   669734 non-null  float64
#  164  航運業(TSE26)收盤_lag_3                    669734 non-null  float64
#  165  鋼鐵(TSE20)收盤_lag_3                     669734 non-null  float64
#  166  預拌混凝土3000磅台北_lag_3                    669734 non-null  float64
#  167  house_index_xyi_all_tp_lag_4          669734 non-null  float64
#  168  house_index_xyi_tp_lag_4              669734 non-null  float64
#  169  house_index_xyi_new_tp_lag_4          669734 non-null  float64
#  170  EB18_lag_4                            669734 non-null  float64
#  171  EB21_lag_4                            669734 non-null  float64
#  172  MC31_lag_4                            669734 non-null  float64
#  173  MC31G_lag_4                           669734 non-null  float64
#  174  MC36_lag_4                            669734 non-null  float64
#  175  NA0101_lag_4                          669734 non-null  float64
#  176  NA1005_lag_4                          669734 non-null  float64
#  177  NB0101_lag_4                          669734 non-null  float64
#  178  NC0117_lag_4                          669734 non-null  float64
#  179  NC0118_lag_4                          669734 non-null  float64
#  180  NE0206_lag_4                          669734 non-null  float64
#  181  PA0120_lag_4                          669734 non-null  float64
#  182  PA1205_lag_4                          669734 non-null  float64
#  183  PE0503_lag_4                          669734 non-null  float64
#  184  TSE收盤_lag_4                           669734 non-null  float64
#  185  水泥(TSE11)收盤_lag_4                     669734 non-null  float64
#  186  建材營造(TSE25)收盤_lag_4                   669734 non-null  float64
#  187  航運業(TSE26)收盤_lag_4                    669734 non-null  float64
#  188  鋼鐵(TSE20)收盤_lag_4                     669734 non-null  float64
#  189  預拌混凝土3000磅台北_lag_4                    669734 non-null  float64
#  190  house_index_xyi_all_tp_lag_5          669734 non-null  float64
#  191  house_index_xyi_tp_lag_5              669734 non-null  float64
#  192  house_index_xyi_new_tp_lag_5          669734 non-null  float64
#  193  EB18_lag_5                            669734 non-null  float64
#  194  EB21_lag_5                            669734 non-null  float64
#  195  MC31_lag_5                            669734 non-null  float64
#  196  MC31G_lag_5                           669734 non-null  float64
#  197  MC36_lag_5                            669734 non-null  float64
#  198  NA0101_lag_5                          669734 non-null  float64
#  199  NA1005_lag_5                          669734 non-null  float64
#  200  NB0101_lag_5                          669734 non-null  float64
#  201  NC0117_lag_5                          669734 non-null  float64
#  202  NC0118_lag_5                          669734 non-null  float64
#  203  NE0206_lag_5                          669734 non-null  float64
#  204  PA0120_lag_5                          669734 non-null  float64
#  205  PA1205_lag_5                          669734 non-null  float64
#  206  PE0503_lag_5                          669734 non-null  float64
#  207  TSE收盤_lag_5                           669734 non-null  float64
#  208  水泥(TSE11)收盤_lag_5                     669734 non-null  float64
#  209  建材營造(TSE25)收盤_lag_5                   669734 non-null  float64
#  210  航運業(TSE26)收盤_lag_5                    669734 non-null  float64
#  211  鋼鐵(TSE20)收盤_lag_5                     669734 non-null  float64
#  212  預拌混凝土3000磅台北_lag_5                    669734 non-null  float64
# dtypes: float64(161), int64(51), period[M](1)
# memory usage: 1.1 GB

# %%
df[ (df['year_month_for_combine'] > '2024-03-31') ].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5298 entries, 664436 to 669733
# Columns: 213 entries, community_name to 預拌混凝土3000磅台北_lag_5
# dtypes: float64(161), int64(51), period[M](1)
# memory usage: 8.6 MB

# %%
df = df.sort_values(by='year_month_for_combine', ascending=True)

# %%
# 轉回datetime物件才可以使用
# df['year_month_for_combine'] = df['year_month_for_combine'].dt.to_timestamp()

# %%
# df['year'] = df['year_month_for_combine'].dt.year

# %%
# df.drop('year_month_for_combine', axis=1, inplace=True)

# %%
train_data = df[df['year_month_for_combine'] <= '2023-03-31']
validation_data = df[ (df['year_month_for_combine'] > '2023-03-31') & (df['year_month_for_combine'] <= '2024-03-31')]
final_test_data = df[ (df['year_month_for_combine'] > '2024-03-31') ]

# %%
train_data.shape, validation_data.shape, final_test_data.shape
# Out:
# ((614268, 213), (50168, 213), (5298, 213))

# %%
validation_data['year_month_for_combine']
# Out:
# 601656    2023-04
# 601671    2023-04
# 601672    2023-04
# 601673    2023-04
# 601674    2023-04
#            ...
# 556861    2024-03
# 556860    2024-03
# 556867    2024-03
# 556859    2024-03
# 556858    2024-03
# Name: year_month_for_combine, Length: 50168, dtype: period[M]

# %%
train_data.info(max_cols=213)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614268 entries, 248513 to 607860
# Data columns (total 213 columns):
#  #    Column                                Non-Null Count   Dtype
# ---   ------                                --------------   -----
#  0    community_name                        614268 non-null  int64
#  1    main_building_ratio                   614268 non-null  float64
#  2    building_age                          614268 non-null  float64
#  3    total_area_ping                       614268 non-null  float64
#  4    total_floors                          614268 non-null  float64
#  5    target_floor                          614268 non-null  float64
#  6    transaction_floors                    614268 non-null  float64
#  7    bedrooms                              614268 non-null  float64
#  8    living_rooms                          614268 non-null  float64
#  9    bathrooms                             614268 non-null  float64
#  10   year_month_for_combine                614268 non-null  period[M]
#  11   new_per_ping                          614268 non-null  float64
#  12   Public_Activity_Space_under_250_m     614268 non-null  float64
#  13   MRT_Exit_under_250_m                  614268 non-null  float64
#  14   Religious_Site_under_250_m            614268 non-null  float64
#  15   School_under_250_m                    614268 non-null  float64
#  16   Kindergarten_under_250_m              614268 non-null  float64
#  17   Convenience_Store_under_250_m         614268 non-null  float64
#  18   Bank_under_250_m                      614268 non-null  float64
#  19   Clinic_under_250_m                    614268 non-null  float64
#  20   Pharmacy_under_250_m                  614268 non-null  float64
#  21   acc_Public_Activity_Space_under_500m  614268 non-null  float64
#  22   acc_Public_Activity_Space_under_750m  614268 non-null  float64
#  23   acc_MRT_Exit_under_500m               614268 non-null  float64
#  24   acc_MRT_Exit_under_750m               614268 non-null  float64
#  25   acc_Religious_Site_under_500m         614268 non-null  float64
#  26   acc_Religious_Site_under_750m         614268 non-null  float64
#  27   acc_Shopping_Area_under_750m          614268 non-null  float64
#  28   acc_School_under_500m                 614268 non-null  float64
#  29   acc_School_under_750m                 614268 non-null  float64
#  30   acc_Hospital_under_500m               614268 non-null  float64
#  31   acc_Hospital_under_750m               614268 non-null  float64
#  32   acc_Gas_Station_under_750m            614268 non-null  float64
#  33   acc_Kindergarten_under_500m           614268 non-null  float64
#  34   acc_Kindergarten_under_750m           614268 non-null  float64
#  35   acc_Daycare_Center_under_500m         614268 non-null  float64
#  36   acc_Daycare_Center_under_750m         614268 non-null  float64
#  37   acc_Convenience_Store_under_500m      614268 non-null  float64
#  38   acc_Convenience_Store_under_750m      614268 non-null  float64
#  39   acc_Bank_under_500m                   614268 non-null  float64
#  40   acc_Bank_under_750m                   614268 non-null  float64
#  41   acc_Police_Station_under_750m         614268 non-null  float64
#  42   acc_Clinic_under_500m                 614268 non-null  float64
#  43   acc_Clinic_under_750m                 614268 non-null  float64
#  44   acc_Pharmacy_under_500m               614268 non-null  float64
#  45   acc_Pharmacy_under_750m               614268 non-null  float64
#  46   acc_Medical_Facility_under_750m       614268 non-null  float64
#  47   has_parking_space                     614268 non-null  int64
#  48   elevator_available                    614268 non-null  int64
#  49   property_type__公寓                     614268 non-null  int64
#  50   property_type__透天厝                    614268 non-null  int64
#  51   property_type__電梯大樓                   614268 non-null  int64
#  52   city__台北市                             614268 non-null  int64
#  53   city__新北市                             614268 non-null  int64
#  54   district__三峽區                         614268 non-null  int64
#  55   district__三芝區                         614268 non-null  int64
#  56   district__三重區                         614268 non-null  int64
#  57   district__中和區                         614268 non-null  int64
#  58   district__中山區                         614268 non-null  int64
#  59   district__中正區                         614268 non-null  int64
#  60   district__五股區                         614268 non-null  int64
#  61   district__信義區                         614268 non-null  int64
#  62   district__內湖區                         614268 non-null  int64
#  63   district__八里區                         614268 non-null  int64
#  64   district__北投區                         614268 non-null  int64
#  65   district__南港區                         614268 non-null  int64
#  66   district__土城區                         614268 non-null  int64
#  67   district__坪林區                         614268 non-null  int64
#  68   district__士林區                         614268 non-null  int64
#  69   district__大同區                         614268 non-null  int64
#  70   district__大安區                         614268 non-null  int64
#  71   district__平溪區                         614268 non-null  int64
#  72   district__文山區                         614268 non-null  int64
#  73   district__新店區                         614268 non-null  int64
#  74   district__新莊區                         614268 non-null  int64
#  75   district__松山區                         614268 non-null  int64
#  76   district__板橋區                         614268 non-null  int64
#  77   district__林口區                         614268 non-null  int64
#  78   district__樹林區                         614268 non-null  int64
#  79   district__永和區                         614268 non-null  int64
#  80   district__汐止區                         614268 non-null  int64
#  81   district__泰山區                         614268 non-null  int64
#  82   district__淡水區                         614268 non-null  int64
#  83   district__深坑區                         614268 non-null  int64
#  84   district__烏來區                         614268 non-null  int64
#  85   district__瑞芳區                         614268 non-null  int64
#  86   district__石碇區                         614268 non-null  int64
#  87   district__石門區                         614268 non-null  int64
#  88   district__萬華區                         614268 non-null  int64
#  89   district__萬里區                         614268 non-null  int64
#  90   district__蘆洲區                         614268 non-null  int64
#  91   district__貢寮區                         614268 non-null  int64
#  92   district__金山區                         614268 non-null  int64
#  93   district__雙溪區                         614268 non-null  int64
#  94   district__鶯歌區                         614268 non-null  int64
#  95   usage_category__住商用                   614268 non-null  int64
#  96   usage_category__住家用                   614268 non-null  int64
#  97   target_index_house_index_xyi_all_tp   614268 non-null  float64
#  98   house_index_xyi_all_tp_lag_1          614268 non-null  float64
#  99   house_index_xyi_tp_lag_1              614268 non-null  float64
#  100  house_index_xyi_new_tp_lag_1          614268 non-null  float64
#  101  EB18_lag_1                            614268 non-null  float64
#  102  EB21_lag_1                            614268 non-null  float64
#  103  MC31_lag_1                            614268 non-null  float64
#  104  MC31G_lag_1                           614268 non-null  float64
#  105  MC36_lag_1                            614268 non-null  float64
#  106  NA0101_lag_1                          614268 non-null  float64
#  107  NA1005_lag_1                          614268 non-null  float64
#  108  NB0101_lag_1                          614268 non-null  float64
#  109  NC0117_lag_1                          614268 non-null  float64
#  110  NC0118_lag_1                          614268 non-null  float64
#  111  NE0206_lag_1                          614268 non-null  float64
#  112  PA0120_lag_1                          614268 non-null  float64
#  113  PA1205_lag_1                          614268 non-null  float64
#  114  PE0503_lag_1                          614268 non-null  float64
#  115  TSE收盤_lag_1                           614268 non-null  float64
#  116  水泥(TSE11)收盤_lag_1                     614268 non-null  float64
#  117  建材營造(TSE25)收盤_lag_1                   614268 non-null  float64
#  118  航運業(TSE26)收盤_lag_1                    614268 non-null  float64
#  119  鋼鐵(TSE20)收盤_lag_1                     614268 non-null  float64
#  120  預拌混凝土3000磅台北_lag_1                    614268 non-null  float64
#  121  house_index_xyi_all_tp_lag_2          614268 non-null  float64
#  122  house_index_xyi_tp_lag_2              614268 non-null  float64
#  123  house_index_xyi_new_tp_lag_2          614268 non-null  float64
#  124  EB18_lag_2                            614268 non-null  float64
#  125  EB21_lag_2                            614268 non-null  float64
#  126  MC31_lag_2                            614268 non-null  float64
#  127  MC31G_lag_2                           614268 non-null  float64
#  128  MC36_lag_2                            614268 non-null  float64
#  129  NA0101_lag_2                          614268 non-null  float64
#  130  NA1005_lag_2                          614268 non-null  float64
#  131  NB0101_lag_2                          614268 non-null  float64
#  132  NC0117_lag_2                          614268 non-null  float64
#  133  NC0118_lag_2                          614268 non-null  float64
#  134  NE0206_lag_2                          614268 non-null  float64
#  135  PA0120_lag_2                          614268 non-null  float64
#  136  PA1205_lag_2                          614268 non-null  float64
#  137  PE0503_lag_2                          614268 non-null  float64
#  138  TSE收盤_lag_2                           614268 non-null  float64
#  139  水泥(TSE11)收盤_lag_2                     614268 non-null  float64
#  140  建材營造(TSE25)收盤_lag_2                   614268 non-null  float64
#  141  航運業(TSE26)收盤_lag_2                    614268 non-null  float64
#  142  鋼鐵(TSE20)收盤_lag_2                     614268 non-null  float64
#  143  預拌混凝土3000磅台北_lag_2                    614268 non-null  float64
#  144  house_index_xyi_all_tp_lag_3          614268 non-null  float64
#  145  house_index_xyi_tp_lag_3              614268 non-null  float64
#  146  house_index_xyi_new_tp_lag_3          614268 non-null  float64
#  147  EB18_lag_3                            614268 non-null  float64
#  148  EB21_lag_3                            614268 non-null  float64
#  149  MC31_lag_3                            614268 non-null  float64
#  150  MC31G_lag_3                           614268 non-null  float64
#  151  MC36_lag_3                            614268 non-null  float64
#  152  NA0101_lag_3                          614268 non-null  float64
#  153  NA1005_lag_3                          614268 non-null  float64
#  154  NB0101_lag_3                          614268 non-null  float64
#  155  NC0117_lag_3                          614268 non-null  float64
#  156  NC0118_lag_3                          614268 non-null  float64
#  157  NE0206_lag_3                          614268 non-null  float64
#  158  PA0120_lag_3                          614268 non-null  float64
#  159  PA1205_lag_3                          614268 non-null  float64
#  160  PE0503_lag_3                          614268 non-null  float64
#  161  TSE收盤_lag_3                           614268 non-null  float64
#  162  水泥(TSE11)收盤_lag_3                     614268 non-null  float64
#  163  建材營造(TSE25)收盤_lag_3                   614268 non-null  float64
#  164  航運業(TSE26)收盤_lag_3                    614268 non-null  float64
#  165  鋼鐵(TSE20)收盤_lag_3                     614268 non-null  float64
#  166  預拌混凝土3000磅台北_lag_3                    614268 non-null  float64
#  167  house_index_xyi_all_tp_lag_4          614268 non-null  float64
#  168  house_index_xyi_tp_lag_4              614268 non-null  float64
#  169  house_index_xyi_new_tp_lag_4          614268 non-null  float64
#  170  EB18_lag_4                            614268 non-null  float64
#  171  EB21_lag_4                            614268 non-null  float64
#  172  MC31_lag_4                            614268 non-null  float64
#  173  MC31G_lag_4                           614268 non-null  float64
#  174  MC36_lag_4                            614268 non-null  float64
#  175  NA0101_lag_4                          614268 non-null  float64
#  176  NA1005_lag_4                          614268 non-null  float64
#  177  NB0101_lag_4                          614268 non-null  float64
#  178  NC0117_lag_4                          614268 non-null  float64
#  179  NC0118_lag_4                          614268 non-null  float64
#  180  NE0206_lag_4                          614268 non-null  float64
#  181  PA0120_lag_4                          614268 non-null  float64
#  182  PA1205_lag_4                          614268 non-null  float64
#  183  PE0503_lag_4                          614268 non-null  float64
#  184  TSE收盤_lag_4                           614268 non-null  float64
#  185  水泥(TSE11)收盤_lag_4                     614268 non-null  float64
#  186  建材營造(TSE25)收盤_lag_4                   614268 non-null  float64
#  187  航運業(TSE26)收盤_lag_4                    614268 non-null  float64
#  188  鋼鐵(TSE20)收盤_lag_4                     614268 non-null  float64
#  189  預拌混凝土3000磅台北_lag_4                    614268 non-null  float64
#  190  house_index_xyi_all_tp_lag_5          614268 non-null  float64
#  191  house_index_xyi_tp_lag_5              614268 non-null  float64
#  192  house_index_xyi_new_tp_lag_5          614268 non-null  float64
#  193  EB18_lag_5                            614268 non-null  float64
#  194  EB21_lag_5                            614268 non-null  float64
#  195  MC31_lag_5                            614268 non-null  float64
#  196  MC31G_lag_5                           614268 non-null  float64
#  197  MC36_lag_5                            614268 non-null  float64
#  198  NA0101_lag_5                          614268 non-null  float64
#  199  NA1005_lag_5                          614268 non-null  float64
#  200  NB0101_lag_5                          614268 non-null  float64
#  201  NC0117_lag_5                          614268 non-null  float64
#  202  NC0118_lag_5                          614268 non-null  float64
#  203  NE0206_lag_5                          614268 non-null  float64
#  204  PA0120_lag_5                          614268 non-null  float64
#  205  PA1205_lag_5                          614268 non-null  float64
#  206  PE0503_lag_5                          614268 non-null  float64
#  207  TSE收盤_lag_5                           614268 non-null  float64
#  208  水泥(TSE11)收盤_lag_5                     614268 non-null  float64
#  209  建材營造(TSE25)收盤_lag_5                   614268 non-null  float64
#  210  航運業(TSE26)收盤_lag_5                    614268 non-null  float64
#  211  鋼鐵(TSE20)收盤_lag_5                     614268 non-null  float64
#  212  預拌混凝土3000磅台北_lag_5                    614268 non-null  float64
# dtypes: float64(161), int64(51), period[M](1)
# memory usage: 1002.9 MB

# %%
X_train = train_data.drop(['new_per_ping', 'year_month_for_combine'], axis=1).values
y_train = train_data['new_per_ping'].values

X_validation = validation_data.drop(['new_per_ping', 'year_month_for_combine'], axis=1).values
y_validation = validation_data['new_per_ping'].values

X_final_test = final_test_data.drop(['new_per_ping', 'year_month_for_combine'], axis=1).values
y_final_test = final_test_data['new_per_ping'].values

# %%
X_train.shape, X_validation.shape, X_final_test.shape
# Out:
# ((614268, 211), (50168, 211), (5298, 211))

# %%
# 非時間間的特徵從[0:119], 時間特徵[120:]
# y每一筆資料只有一個值，就不用動了

# train
non_time_train = X_train[:,0:95]
time_series_train = X_train[:,96:] # 119是時間序列月的target_y，就先不要了

# validation
non_time_validation = X_validation[:,0:95]
time_series_validation = X_validation[:,96:]

# # test
non_time_test = X_final_test[:,0:95]
time_series_test = X_final_test[:,96:]

# %%
print(non_time_train.shape)
print(time_series_train.shape)
print(time_series_test.shape)
# Out:
# (614268, 95)
# (614268, 115)
# (5298, 115)

# %% [markdown]
# ## 處理正規化、正則化
# * 我知道了non_time就用minmax(這樣特徵就可以保持原樣了...)記先這樣吧
# * times就用standardlize

# %%
# 非時間特徵用的(這樣one-hot的欄位不受影響，真要要用StandardScaler就要切蘭為了)
from sklearn.preprocessing import MinMaxScaler
mm_scaler_for_non = MinMaxScaler()
non_time_train = mm_scaler_for_non.fit_transform(non_time_train) # 只有訓練資料可以fit，之後都使用訓練資料fit出來的結果作transform
non_time_validation = mm_scaler_for_non.transform(non_time_validation)
non_time_test = mm_scaler_for_non.transform(non_time_test)

# 時間特徵用的(使用標準化的效果校佳)
from sklearn.preprocessing import StandardScaler
scaler_for_time = StandardScaler()
time_series_train = scaler_for_time.fit_transform(time_series_train)
time_series_validation = scaler_for_time.transform(time_series_validation)
time_series_test = scaler_for_time.transform(time_series_test)


## 試試看統一用minmaxscaler
# from sklearn.preprocessing import StandardScaler
# scaler_for_time = MinMaxScaler()
# time_series_train = scaler_for_time.fit_transform(time_series_train)
# time_series_validation = scaler_for_time.transform(time_series_validation)
# time_series_test = scaler_for_time.transform(time_series_test)

# %% [markdown]
# ## 先來處理非時間特徵模型

# %%
feature_shape = non_time_train.shape[1]

# %%
# 非時間特徵的模型
# 定義模型層數堆疊 (以class Model建立模型的方式，就只是每一層都有一個輸出，然後下一層繼續接輸出而以)
input_non_time_feature = Input(shape=feature_shape)
y = Dense(64, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42), kernel_regularizer= tf.keras.regularizers.l2(0.001),)(input_non_time_feature)
# y = Dense(64, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(y)
# y = Dense(64, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(y)
# y = Dense(64, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(y)
# y = Dense(64, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42), kernel_regularizer= tf.keras.regularizers.l2(0.001))(y)
# y = Dense(64, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42), kernel_regularizer= tf.keras.regularizers.l2(0.001))(y)
y = Dense(32, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42), kernel_regularizer= tf.keras.regularizers.l2(0.001))(y)
y = Dense(32, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42), kernel_regularizer= tf.keras.regularizers.l2(0.001),)(y)
model_non_time = Model(inputs=input_non_time_feature, outputs=y)

# %% [markdown]
# ## 時間相關的的特徵整理與模型

# %%
# 更改成可以餵入ConV1D的形式
# 拿來放要用的資料形式(X:2D)
arry_index = time_series_train.shape[0] # 抓總筆數
X_shift_list = []

for each_index in range(arry_index):
    # 每一筆資料抓出來
    each_array = time_series_train[each_index].reshape(5,23)

    X_shift_list.append(each_array)

# %%
# list要轉乘array才可以丟模型
X_times_train = np.array(X_shift_list)
X_times_train.shape
# Out:
# (614268, 5, 23)

# %%
arry_index_v = time_series_validation.shape[0] # 抓總筆數   # time_series_validation
X_shift_list_v = []

for each_index in range(arry_index_v):
    # 每一筆資料抓出來
    each_array_v = time_series_validation[each_index].reshape(5,23)

    X_shift_list_v.append(each_array_v)

X_times_validation = np.array(X_shift_list_v)
X_times_validation.shape
# Out:
# (50168, 5, 23)

# %%
arry_index_t = time_series_test.shape[0] # 抓總筆數   # time_series_test
X_shift_list_t = []

for each_index in range(arry_index_t):
    # 每一筆資料抓出來
    each_array_t = time_series_test[each_index].reshape(5,23)

    X_shift_list_t.append(each_array_t)

X_times_test = np.array(X_shift_list_t)
X_times_test.shape
# Out:
# (5298, 5, 23)

# %%
# 定義Conv1D模型 (這樣堆疊是可以的)
time_feature_input = Input(shape=(5, 23))  # (#timestamp=5, #feature=36)
x = Conv1D(filters=32, kernel_size=3, strides=1, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(time_feature_input)
x = BatchNormalization()(x)
# x = CBAMLayer(channel=32)(x) # channels數要與上一層的Conv1D filters數一樣
x = BatchNormalization()(x)
x = Conv1D(filters=64, kernel_size=3, strides=1, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(x)
x = BatchNormalization()(x)
# x = Dropout(0.5)(x)
# x = Bidirectional(LSTM(6, return_sequences=True))(x)
# x = Bidirectional(LSTM(6, return_sequences=True))(x)
x = Flatten()(x)
x = Dense(32, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(x)
# x = Dense(64, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(x)
# x = Dropout(0.5)(x)
# x = Dense(16, activation='relu', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(x)
time_model = Model(inputs=time_feature_input, outputs=x)

# %% [markdown]
# ## 幾個epoch就做保存模型的動作，若要繼續續練模型，只需要加載回原先儲存的模型，繼續.fit()就會繼續訓練拉

# %%
from tensorflow.keras.callbacks import ModelCheckpoint # 使用此設定每幾個epoch就儲存一次模型
checkpoint_seq = ModelCheckpoint('/content/my_drive/MyDrive/BDSE34期末報告_房價/trained_models/full_data_version_with_time_split_CNN_CBAM{epoch:03d}.h5', save_freq='epoch', period=15)
# model_seq_{epoch:03d}.h5這應該是檔名?!        # save_freq=<數值>，表示多少batch儲存一次模型(注意每過一個batch size是一個iteration)，看過全部資料才是一個Epoch
# period有可能不能用，有問題的話注意一下

### 並在模型訓練時透過callbacks參數指定(設定)
# model_seq.fit(X_seq, y_true, epochs=1000, batch_size=32, callbacks=[checkpoint_seq])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## 其他定義
# * EarlyStopping
# * LearningRateScheduler
# * cc(corelation coefficeint) 驗證用

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=25, verbose=1, mode='min', restore_best_weights=True)

# %%
# import math
# from keras.callbacks import LearningRateScheduler
# def scheduler(epoch, lr):
#     if epoch < 10:
#         return lr
#     if epoch < 30:
#         lr = 0.005
#         return lr
#     if epoch < 50:
#         lr = 0.0001
#         return lr
#     else:
#         return lr * math.exp(-0.1)

# lr_Scheduler = LearningRateScheduler(scheduler)

import math
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    # if epoch < 30:
    #     lr = 0.001
    #     return lr
    else:
      decay = 0.0001
      return lr * math.exp(-0.1)
        # return lr * math.exp(-0.1)

lr_Scheduler = LearningRateScheduler(scheduler)

# %%
def cc(y_true, y_pred):
    """
    計算 y_true 和 y_pred 之間的相關係數。
    """
    # 計算協方差矩陣
    cov = tfp.stats.covariance(y_true, y_pred, sample_axis=0)

    # 計算 y_true 和 y_pred 的標準差
    std_true = K.std(y_true)
    std_pred = K.std(y_pred)

    # 計算相關係數
    return cov / (std_true * std_pred)

# %% [markdown]
# ## concat NNs

# %%
from tensorflow.keras.layers import concatenate

# 拼接兩個模型的輸出
combined = concatenate([time_model.output, model_non_time.output])
z = Dense(64, activation='relu', kernel_regularizer= tf.keras.regularizers.l2(0.001), kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(combined)
# z = Dense(64, activation='linear', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(z)
# z = Dense(64, activation='linear', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(z)
# z = Dense(64, activation='linear', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(z)
# z = Dense(32, activation='relu', kernel_regularizer= tf.keras.regularizers.l2(0.001), kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(z)
# z = Dense(32, activation='relu', kernel_regularizer= tf.keras.regularizers.l2(0.001), kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(z)
# z = Dense(32, activation='relu', kernel_regularizer= tf.keras.regularizers.l2(0.001), kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(z)
# z = Dense(32, activation='relu', kernel_regularizer= tf.keras.regularizers.l2(0.001), kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(z)
z = Dense(32, activation='relu', kernel_regularizer= tf.keras.regularizers.l2(0.001), kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42))(z)
z = Dense(1, activation='linear', kernel_initializer=tf.keras.initializers.GlorotUniform(seed=42) )(z)  # 假設最後輸出是一個回歸值

# 定義最終的模型
model_combined = Model(inputs=[time_model.input, model_non_time.input], outputs=z)

# %%
model_combined.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 5, 23)]              0         []
#
#  conv1d (Conv1D)             (None, 3, 32)                2240      ['input_2[0][0]']
#
#  batch_normalization (Batch  (None, 3, 32)                128       ['conv1d[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 3, 32)                128       ['batch_normalization[0][0]']
#  chNormalization)
#
#  conv1d_1 (Conv1D)           (None, 1, 64)                6208      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  input_1 (InputLayer)        [(None, 95)]                 0         []
#
#  batch_normalization_2 (Bat  (None, 1, 64)                256       ['conv1d_1[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 64)                   6144      ['input_1[0][0]']
#
#  flatten (Flatten)           (None, 64)                   0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, 32)                   2080      ['dense[0][0]']
#
#  dense_3 (Dense)             (None, 32)                   2080      ['flatten[0][0]']
#
#  dense_2 (Dense)             (None, 32)                   1056      ['dense_1[0][0]']
#
#  concatenate (Concatenate)   (None, 64)                   0         ['dense_3[0][0]',
#                                                                      'dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   4160      ['concatenate[0][0]']
#
#  dense_5 (Dense)             (None, 32)                   2080      ['dense_4[0][0]']
#
#  dense_6 (Dense)             (None, 1)                    33        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 26593 (103.88 KB)
# Trainable params: 26337 (102.88 KB)
# Non-trainable params: 256 (1.00 KB)
# __________________________________________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
# 編譯模型
model_combined.compile(optimizer=optimizer, loss='mean_squared_error', metrics=[RootMeanSquaredError() , MeanAbsoluteError(), cc])

# %%
history = model_combined.fit([X_times_train, non_time_train], y_train, epochs=1000, batch_size=128, validation_data=([X_times_validation, non_time_validation], y_validation), callbacks=[checkpoint_seq, lr_Scheduler, early_stopping])
# Out:
# Epoch 1/1000
# 4799/4799 [==============================] - 20s 4ms/step - loss: 17633153024.0000 - root_mean_squared_error: 132789.8906 - mean_absolute_error: 84631.0156 - cc: 0.8090 - val_loss: 14872743936.0000 - val_root_mean_squared_error: 121953.8594 - val_mean_absolute_error: 85800.1562 - val_cc: 0.6849 - lr: 0.0010
# Epoch 2/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 10403574784.0000 - root_mean_squared_error: 101997.9141 - mean_absolute_error: 67433.6953 - cc: 0.8520 - val_loss: 13904276480.0000 - val_root_mean_squared_error: 117916.3984 - val_mean_absolute_error: 81909.5156 - val_cc: 0.7147 - lr: 0.0010
# Epoch 3/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 9874471936.0000 - root_mean_squared_error: 99370.3750 - mean_absolute_error: 65060.5703 - cc: 0.8604 - val_loss: 13243457536.0000 - val_root_mean_squared_error: 115080.2188 - val_mean_absolute_error: 79380.5625 - val_cc: 0.7267 - lr: 0.0010
# Epoch 4/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 9563514880.0000 - root_mean_squared_error: 97793.2266 - mean_absolute_error: 63640.1406 - cc: 0.8654 - val_loss: 13324841984.0000 - val_root_mean_squared_error: 115433.2812 - val_mean_absolute_error: 79601.2344 - val_cc: 0.7324 - lr: 0.0010
# Epoch 5/1000
# 4799/4799 [==============================] - 17s 4ms/step - loss: 9329563648.0000 - root_mean_squared_error: 96589.6641 - mean_absolute_error: 62566.1836 - cc: 0.8687 - val_loss: 12887177216.0000 - val_root_mean_squared_error: 113521.7031 - val_mean_absolute_error: 78120.4062 - val_cc: 0.7381 - lr: 0.0010
# Epoch 6/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 9159217152.0000 - root_mean_squared_error: 95703.7969 - mean_absolute_error: 61834.6133 - cc: 0.8713 - val_loss: 13119572992.0000 - val_root_mean_squared_error: 114540.7031 - val_mean_absolute_error: 79310.0312 - val_cc: 0.7412 - lr: 0.0010
# Epoch 7/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 9018258432.0000 - root_mean_squared_error: 94964.5078 - mean_absolute_error: 61143.8945 - cc: 0.8735 - val_loss: 12761567232.0000 - val_root_mean_squared_error: 112967.1094 - val_mean_absolute_error: 77698.1875 - val_cc: 0.7423 - lr: 0.0010
# Epoch 8/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 8907755520.0000 - root_mean_squared_error: 94380.9062 - mean_absolute_error: 60586.4648 - cc: 0.8752 - val_loss: 12268039168.0000 - val_root_mean_squared_error: 110761.1797 - val_mean_absolute_error: 75227.1250 - val_cc: 0.7490 - lr: 0.0010
# Epoch 9/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 8794002432.0000 - root_mean_squared_error: 93776.3438 - mean_absolute_error: 60023.1094 - cc: 0.8770 - val_loss: 11985584128.0000 - val_root_mean_squared_error: 109478.6953 - val_mean_absolute_error: 73478.2578 - val_cc: 0.7527 - lr: 0.0010
# Epoch 10/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 8681061376.0000 - root_mean_squared_error: 93172.2109 - mean_absolute_error: 59530.0781 - cc: 0.8785 - val_loss: 11931822080.0000 - val_root_mean_squared_error: 109232.8828 - val_mean_absolute_error: 73744.3672 - val_cc: 0.7555 - lr: 0.0010
# Epoch 11/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 8585254400.0000 - root_mean_squared_error: 92656.6484 - mean_absolute_error: 59086.7266 - cc: 0.8798 - val_loss: 12355518464.0000 - val_root_mean_squared_error: 111155.3828 - val_mean_absolute_error: 77011.2109 - val_cc: 0.7563 - lr: 9.0484e-04
# Epoch 12/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 8496150528.0000 - root_mean_squared_error: 92174.5625 - mean_absolute_error: 58658.7500 - cc: 0.8812 - val_loss: 11668314112.0000 - val_root_mean_squared_error: 108019.9688 - val_mean_absolute_error: 72551.3359 - val_cc: 0.7597 - lr: 8.1873e-04
# Epoch 13/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 8415473664.0000 - root_mean_squared_error: 91735.8906 - mean_absolute_error: 58289.1953 - cc: 0.8824 - val_loss: 11767554048.0000 - val_root_mean_squared_error: 108478.3594 - val_mean_absolute_error: 73390.9375 - val_cc: 0.7618 - lr: 7.4082e-04
# Epoch 14/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 8342218240.0000 - root_mean_squared_error: 91335.7422 - mean_absolute_error: 57956.9453 - cc: 0.8834 - val_loss: 12012203008.0000 - val_root_mean_squared_error: 109600.1953 - val_mean_absolute_error: 74887.5938 - val_cc: 0.7627 - lr: 6.7032e-04
# Epoch 15/1000
# 4787/4799 [============================>.] - ETA: 0s - loss: 8267461120.0000 - root_mean_squared_error: 90925.5781 - mean_absolute_error: 57615.2539 - cc: 0.8844
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4799/4799 [==============================] - 19s 4ms/step - loss: 8268192256.0000 - root_mean_squared_error: 90929.6016 - mean_absolute_error: 57617.2734 - cc: 0.8844 - val_loss: 11969273856.0000 - val_root_mean_squared_error: 109404.1797 - val_mean_absolute_error: 75212.5547 - val_cc: 0.7630 - lr: 6.0653e-04
# Epoch 16/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 8203661312.0000 - root_mean_squared_error: 90574.0625 - mean_absolute_error: 57296.0977 - cc: 0.8855 - val_loss: 11525720064.0000 - val_root_mean_squared_error: 107357.9062 - val_mean_absolute_error: 72269.0000 - val_cc: 0.7657 - lr: 5.4881e-04
# Epoch 17/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 8147848192.0000 - root_mean_squared_error: 90265.4297 - mean_absolute_error: 57041.9688 - cc: 0.8863 - val_loss: 11401723904.0000 - val_root_mean_squared_error: 106778.8516 - val_mean_absolute_error: 71864.4609 - val_cc: 0.7663 - lr: 4.9659e-04
# Epoch 18/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 8095028224.0000 - root_mean_squared_error: 89972.3750 - mean_absolute_error: 56819.2461 - cc: 0.8869 - val_loss: 11430747136.0000 - val_root_mean_squared_error: 106914.6719 - val_mean_absolute_error: 72133.7969 - val_cc: 0.7665 - lr: 4.4933e-04
# Epoch 19/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 8051716096.0000 - root_mean_squared_error: 89731.3516 - mean_absolute_error: 56590.4375 - cc: 0.8876 - val_loss: 11403794432.0000 - val_root_mean_squared_error: 106788.5469 - val_mean_absolute_error: 71939.9375 - val_cc: 0.7683 - lr: 4.0657e-04
# Epoch 20/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 8010540032.0000 - root_mean_squared_error: 89501.6172 - mean_absolute_error: 56400.1289 - cc: 0.8882 - val_loss: 11888120832.0000 - val_root_mean_squared_error: 109032.6562 - val_mean_absolute_error: 74940.0156 - val_cc: 0.7696 - lr: 3.6788e-04
# Epoch 21/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7973623808.0000 - root_mean_squared_error: 89295.1484 - mean_absolute_error: 56242.2695 - cc: 0.8886 - val_loss: 11269731328.0000 - val_root_mean_squared_error: 106158.9922 - val_mean_absolute_error: 71295.3906 - val_cc: 0.7704 - lr: 3.3287e-04
# Epoch 22/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7941487104.0000 - root_mean_squared_error: 89115.0234 - mean_absolute_error: 56077.5547 - cc: 0.8891 - val_loss: 11411663872.0000 - val_root_mean_squared_error: 106825.3906 - val_mean_absolute_error: 72439.6953 - val_cc: 0.7690 - lr: 3.0119e-04
# Epoch 23/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7916756992.0000 - root_mean_squared_error: 88976.1562 - mean_absolute_error: 55942.5195 - cc: 0.8894 - val_loss: 11308650496.0000 - val_root_mean_squared_error: 106342.1406 - val_mean_absolute_error: 71573.2344 - val_cc: 0.7710 - lr: 2.7253e-04
# Epoch 24/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7893996544.0000 - root_mean_squared_error: 88848.1641 - mean_absolute_error: 55844.1875 - cc: 0.8898 - val_loss: 11270298624.0000 - val_root_mean_squared_error: 106161.6641 - val_mean_absolute_error: 71496.4453 - val_cc: 0.7718 - lr: 2.4660e-04
# Epoch 25/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7870468096.0000 - root_mean_squared_error: 88715.6562 - mean_absolute_error: 55735.5508 - cc: 0.8903 - val_loss: 11329558528.0000 - val_root_mean_squared_error: 106440.3984 - val_mean_absolute_error: 71879.0156 - val_cc: 0.7714 - lr: 2.2313e-04
# Epoch 26/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7850832896.0000 - root_mean_squared_error: 88604.9297 - mean_absolute_error: 55627.2227 - cc: 0.8903 - val_loss: 11281408000.0000 - val_root_mean_squared_error: 106213.9766 - val_mean_absolute_error: 71638.7812 - val_cc: 0.7722 - lr: 2.0190e-04
# Epoch 27/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7833319936.0000 - root_mean_squared_error: 88506.0469 - mean_absolute_error: 55546.4609 - cc: 0.8907 - val_loss: 11286533120.0000 - val_root_mean_squared_error: 106238.0938 - val_mean_absolute_error: 71686.5859 - val_cc: 0.7723 - lr: 1.8268e-04
# Epoch 28/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7817900544.0000 - root_mean_squared_error: 88418.8906 - mean_absolute_error: 55479.4180 - cc: 0.8907 - val_loss: 11229663232.0000 - val_root_mean_squared_error: 105970.1016 - val_mean_absolute_error: 71368.2422 - val_cc: 0.7717 - lr: 1.6530e-04
# Epoch 29/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7806001152.0000 - root_mean_squared_error: 88351.5781 - mean_absolute_error: 55413.7812 - cc: 0.8911 - val_loss: 11711870976.0000 - val_root_mean_squared_error: 108221.3984 - val_mean_absolute_error: 74289.1875 - val_cc: 0.7715 - lr: 1.4957e-04
# Epoch 30/1000
# 4799/4799 [==============================] - 17s 4ms/step - loss: 7792761856.0000 - root_mean_squared_error: 88276.6250 - mean_absolute_error: 55360.2969 - cc: 0.8911 - val_loss: 11233371136.0000 - val_root_mean_squared_error: 105987.6016 - val_mean_absolute_error: 71450.2422 - val_cc: 0.7729 - lr: 1.3534e-04
# Epoch 31/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7780363264.0000 - root_mean_squared_error: 88206.3672 - mean_absolute_error: 55281.9297 - cc: 0.8912 - val_loss: 11312092160.0000 - val_root_mean_squared_error: 106358.3203 - val_mean_absolute_error: 72261.4453 - val_cc: 0.7731 - lr: 1.2246e-04
# Epoch 32/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7770179072.0000 - root_mean_squared_error: 88148.6172 - mean_absolute_error: 55230.5703 - cc: 0.8915 - val_loss: 11143574528.0000 - val_root_mean_squared_error: 105563.1328 - val_mean_absolute_error: 70875.7734 - val_cc: 0.7731 - lr: 1.1080e-04
# Epoch 33/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7760133632.0000 - root_mean_squared_error: 88091.6172 - mean_absolute_error: 55196.1133 - cc: 0.8918 - val_loss: 11213028352.0000 - val_root_mean_squared_error: 105891.5859 - val_mean_absolute_error: 71582.1172 - val_cc: 0.7739 - lr: 1.0026e-04
# Epoch 34/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7753096192.0000 - root_mean_squared_error: 88051.6641 - mean_absolute_error: 55158.2070 - cc: 0.8918 - val_loss: 11264058368.0000 - val_root_mean_squared_error: 106132.2656 - val_mean_absolute_error: 71824.9531 - val_cc: 0.7736 - lr: 9.0718e-05
# Epoch 35/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7746381312.0000 - root_mean_squared_error: 88013.5312 - mean_absolute_error: 55120.9375 - cc: 0.8918 - val_loss: 11109573632.0000 - val_root_mean_squared_error: 105401.9609 - val_mean_absolute_error: 70682.6953 - val_cc: 0.7738 - lr: 8.2085e-05
# Epoch 36/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7737589248.0000 - root_mean_squared_error: 87963.5703 - mean_absolute_error: 55092.4102 - cc: 0.8920 - val_loss: 11188073472.0000 - val_root_mean_squared_error: 105773.6875 - val_mean_absolute_error: 71347.4766 - val_cc: 0.7739 - lr: 7.4274e-05
# Epoch 37/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7731433984.0000 - root_mean_squared_error: 87928.5703 - mean_absolute_error: 55042.6445 - cc: 0.8918 - val_loss: 11176512512.0000 - val_root_mean_squared_error: 105719.0234 - val_mean_absolute_error: 71254.0156 - val_cc: 0.7734 - lr: 6.7206e-05
# Epoch 38/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7724680704.0000 - root_mean_squared_error: 87890.1641 - mean_absolute_error: 55029.0742 - cc: 0.8921 - val_loss: 11246900224.0000 - val_root_mean_squared_error: 106051.4062 - val_mean_absolute_error: 71740.6484 - val_cc: 0.7744 - lr: 6.0810e-05
# Epoch 39/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7720770048.0000 - root_mean_squared_error: 87867.9141 - mean_absolute_error: 54998.9414 - cc: 0.8923 - val_loss: 11223075840.0000 - val_root_mean_squared_error: 105939.0156 - val_mean_absolute_error: 71703.4609 - val_cc: 0.7739 - lr: 5.5023e-05
# Epoch 40/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7715578880.0000 - root_mean_squared_error: 87838.3672 - mean_absolute_error: 54981.4375 - cc: 0.8921 - val_loss: 11127692288.0000 - val_root_mean_squared_error: 105487.8750 - val_mean_absolute_error: 70974.1953 - val_cc: 0.7742 - lr: 4.9787e-05
# Epoch 41/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7710690304.0000 - root_mean_squared_error: 87810.5391 - mean_absolute_error: 54958.5430 - cc: 0.8922 - val_loss: 11169878016.0000 - val_root_mean_squared_error: 105687.6406 - val_mean_absolute_error: 71271.3516 - val_cc: 0.7744 - lr: 4.5049e-05
# Epoch 42/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7708312064.0000 - root_mean_squared_error: 87796.9922 - mean_absolute_error: 54938.8867 - cc: 0.8925 - val_loss: 11219382272.0000 - val_root_mean_squared_error: 105921.5859 - val_mean_absolute_error: 71727.5625 - val_cc: 0.7744 - lr: 4.0762e-05
# Epoch 43/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7704875520.0000 - root_mean_squared_error: 87777.4219 - mean_absolute_error: 54924.9141 - cc: 0.8924 - val_loss: 11253851136.0000 - val_root_mean_squared_error: 106084.1719 - val_mean_absolute_error: 71890.0625 - val_cc: 0.7744 - lr: 3.6883e-05
# Epoch 44/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7700441600.0000 - root_mean_squared_error: 87752.1562 - mean_absolute_error: 54912.4609 - cc: 0.8926 - val_loss: 11160810496.0000 - val_root_mean_squared_error: 105644.7344 - val_mean_absolute_error: 71287.6953 - val_cc: 0.7745 - lr: 3.3373e-05
# Epoch 45/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7697548800.0000 - root_mean_squared_error: 87735.6719 - mean_absolute_error: 54890.9180 - cc: 0.8924 - val_loss: 11196303360.0000 - val_root_mean_squared_error: 105812.5859 - val_mean_absolute_error: 71563.1875 - val_cc: 0.7743 - lr: 3.0197e-05
# Epoch 46/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7694689792.0000 - root_mean_squared_error: 87719.3828 - mean_absolute_error: 54882.9961 - cc: 0.8924 - val_loss: 11181930496.0000 - val_root_mean_squared_error: 105744.6484 - val_mean_absolute_error: 71385.4141 - val_cc: 0.7747 - lr: 2.7324e-05
# Epoch 47/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7692360704.0000 - root_mean_squared_error: 87706.1016 - mean_absolute_error: 54876.0117 - cc: 0.8927 - val_loss: 11180836864.0000 - val_root_mean_squared_error: 105739.4766 - val_mean_absolute_error: 71476.0156 - val_cc: 0.7744 - lr: 2.4724e-05
# Epoch 48/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7690314752.0000 - root_mean_squared_error: 87694.4375 - mean_absolute_error: 54855.7852 - cc: 0.8925 - val_loss: 11176522752.0000 - val_root_mean_squared_error: 105719.0781 - val_mean_absolute_error: 71410.1484 - val_cc: 0.7747 - lr: 2.2371e-05
# Epoch 49/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7689065984.0000 - root_mean_squared_error: 87687.3203 - mean_absolute_error: 54853.8711 - cc: 0.8926 - val_loss: 11199426560.0000 - val_root_mean_squared_error: 105827.3438 - val_mean_absolute_error: 71588.8203 - val_cc: 0.7745 - lr: 2.0242e-05
# Epoch 50/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7686285824.0000 - root_mean_squared_error: 87671.4688 - mean_absolute_error: 54840.4062 - cc: 0.8924 - val_loss: 11199259648.0000 - val_root_mean_squared_error: 105826.5547 - val_mean_absolute_error: 71592.9766 - val_cc: 0.7746 - lr: 1.8316e-05
# Epoch 51/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7684896768.0000 - root_mean_squared_error: 87663.5469 - mean_absolute_error: 54834.8359 - cc: 0.8924 - val_loss: 11167129600.0000 - val_root_mean_squared_error: 105674.6406 - val_mean_absolute_error: 71332.2891 - val_cc: 0.7747 - lr: 1.6573e-05
# Epoch 52/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7684273664.0000 - root_mean_squared_error: 87659.9922 - mean_absolute_error: 54830.8047 - cc: 0.8926 - val_loss: 11164573696.0000 - val_root_mean_squared_error: 105662.5469 - val_mean_absolute_error: 71327.7109 - val_cc: 0.7746 - lr: 1.4996e-05
# Epoch 53/1000
# 4799/4799 [==============================] - 16s 3ms/step - loss: 7682673152.0000 - root_mean_squared_error: 87650.8594 - mean_absolute_error: 54827.4844 - cc: 0.8928 - val_loss: 11138028544.0000 - val_root_mean_squared_error: 105536.8594 - val_mean_absolute_error: 71123.8750 - val_cc: 0.7747 - lr: 1.3569e-05
# Epoch 54/1000
# 4799/4799 [==============================] - 17s 4ms/step - loss: 7680590848.0000 - root_mean_squared_error: 87638.9766 - mean_absolute_error: 54813.9336 - cc: 0.8929 - val_loss: 11161253888.0000 - val_root_mean_squared_error: 105646.8359 - val_mean_absolute_error: 71299.0156 - val_cc: 0.7747 - lr: 1.2277e-05
# Epoch 55/1000
# 4799/4799 [==============================] - 18s 4ms/step - loss: 7680269824.0000 - root_mean_squared_error: 87637.1484 - mean_absolute_error: 54813.1680 - cc: 0.8927 - val_loss: 11147428864.0000 - val_root_mean_squared_error: 105581.3828 - val_mean_absolute_error: 71202.8594 - val_cc: 0.7746 - lr: 1.1109e-05
# Epoch 56/1000
# 4799/4799 [==============================] - 17s 4ms/step - loss: 7680038912.0000 - root_mean_squared_error: 87635.8281 - mean_absolute_error: 54815.7188 - cc: 0.8926 - val_loss: 11142855680.0000 - val_root_mean_squared_error: 105559.7266 - val_mean_absolute_error: 71169.2734 - val_cc: 0.7747 - lr: 1.0052e-05
# Epoch 57/1000
# 4799/4799 [==============================] - 17s 4ms/step - loss: 7678905344.0000 - root_mean_squared_error: 87629.3672 - mean_absolute_error: 54803.1602 - cc: 0.8928 - val_loss: 11155985408.0000 - val_root_mean_squared_error: 105621.8984 - val_mean_absolute_error: 71277.4375 - val_cc: 0.7748 - lr: 9.0953e-06
# Epoch 58/1000
# 4799/4799 [==============================] - 17s 4ms/step - loss: 7677931008.0000 - root_mean_squared_error: 87623.8047 - mean_absolute_error: 54800.4492 - cc: 0.8928 - val_loss: 11169562624.0000 - val_root_mean_squared_error: 105686.1484 - val_mean_absolute_error: 71381.8125 - val_cc: 0.7747 - lr: 8.2297e-06
# Epoch 59/1000
# 4799/4799 [==============================] - 17s 3ms/step - loss: 7676846592.0000 - root_mean_squared_error: 87617.6172 - mean_absolute_error: 54799.6719 - cc: 0.8927 - val_loss: 11127371776.0000 - val_root_mean_squared_error: 105486.3594 - val_mean_absolute_error: 71072.4922 - val_cc: 0.7748 - lr: 7.4466e-06
# Epoch 60/1000
# 4796/4799 [============================>.] - ETA: 0s - loss: 7676796416.0000 - root_mean_squared_error: 87617.3281 - mean_absolute_error: 54791.0273 - cc: 0.8927Restoring model weights from the end of the best epoch: 35.
# 4799/4799 [==============================] - 25s 5ms/step - loss: 7676043264.0000 - root_mean_squared_error: 87613.0312 - mean_absolute_error: 54789.8633 - cc: 0.8927 - val_loss: 11147662336.0000 - val_root_mean_squared_error: 105582.4922 - val_mean_absolute_error: 71221.8125 - val_cc: 0.7748 - lr: 6.7379e-06
# Epoch 60: early stopping

# %%
# 看每一層的shape
model_combined.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 5, 23)]              0         []
#
#  conv1d (Conv1D)             (None, 3, 32)                2240      ['input_2[0][0]']
#
#  batch_normalization (Batch  (None, 3, 32)                128       ['conv1d[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 3, 32)                128       ['batch_normalization[0][0]']
#  chNormalization)
#
#  conv1d_1 (Conv1D)           (None, 1, 64)                6208      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  input_1 (InputLayer)        [(None, 95)]                 0         []
#
#  batch_normalization_2 (Bat  (None, 1, 64)                256       ['conv1d_1[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 64)                   6144      ['input_1[0][0]']
#
#  flatten (Flatten)           (None, 64)                   0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, 32)                   2080      ['dense[0][0]']
#
#  dense_3 (Dense)             (None, 32)                   2080      ['flatten[0][0]']
#
#  dense_2 (Dense)             (None, 32)                   1056      ['dense_1[0][0]']
#
#  concatenate (Concatenate)   (None, 64)                   0         ['dense_3[0][0]',
#                                                                      'dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   4160      ['concatenate[0][0]']
#
#  dense_5 (Dense)             (None, 32)                   2080      ['dense_4[0][0]']
#
#  dense_6 (Dense)             (None, 1)                    33        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 26593 (103.88 KB)
# Trainable params: 26337 (102.88 KB)
# Non-trainable params: 256 (1.00 KB)
# __________________________________________________________________________________________________

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.plot(history.history['root_mean_squared_error'], label='Training RMSE')
plt.plot(history.history['val_root_mean_squared_error'], label='Validation RMSE')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
#### 存檔用
model_combined.save('/content/my_drive/MyDrive/BDSE34期末報告_房價/stacking_models/c591_only_CNN_0710.h5') # 模型的副檔名記得是.h5

# %% [markdown]
# # testing set

# %%
X_times_test.shape
# Out:
# (5298, 5, 23)

# %%
pred_y_test = model_combined.predict([X_times_test, non_time_test])
# Out:
# 166/166 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
def rmse(predictions, targets):
    return np.sqrt(mean_squared_error(predictions, targets))

# %%
# NN 的validation跟test是偏像的

print(f"test mae:{mean_absolute_error(pred_y_test, y_final_test)}")
print(f"test RMSE:{rmse(pred_y_test, y_final_test)}")
r2_score_linear_train = r2_score(y_final_test, pred_y_test)
print('R2_score (test): ', r2_score_linear_train)
print('-'*50)
# Out:
# test mae:81148.19931837486
# test RMSE:115122.04939281062
# R2_score (test):  0.7476859747989691
# --------------------------------------------------

# %%
final_test_data['new_per_ping'].describe()
# Out:
# count    5.298000e+03
# mean     5.002125e+05
# std      2.292075e+05
# min      2.645503e+04
# 25%      3.393590e+05
# 50%      4.683932e+05
# 75%      6.286080e+05
# max      1.443124e+06
# Name: new_per_ping, dtype: float64

# %% [markdown]
# # 591資料驗證

# %%
df_591 = pd.read_csv('/content/my_drive/MyDrive/BDSE34期末報告_房價/all_data/c591_no_eco_for_xgb_version3.csv', encoding='utf-8')

# %%
df_591['year_month_for_combine'] = '2024-06-01'

# %%
df_591['year_month_for_combine'] = pd.to_datetime(df_591['year_month_for_combine']).dt.to_period('M')

# %%
only_eco_file_path = '/content/my_drive/MyDrive/BDSE34期末報告_房價/all_data/final_eco_df_to_11306_fillna_v2.csv'
only_eco_df = pd.read_csv(only_eco_file_path, encoding='utf-8')

# %%
only_eco_df.drop('year_month_for_combine', axis=1, inplace=True)

# %%
window_df_591 = create_windows_of_each_eco_index(only_eco_df, 5)
# Out:
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)
# <ipython-input-9-abb8de1a450b>:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars_shift_df[f'{var}_lag_{lag}'] = only_eco_df[var].shift(lag)

# %%
window_df_591['date'] = pd.to_datetime(window_df_591['date'])
window_df_591['year_month_for_combine'] = window_df_591['date'].dt.to_period('M')
# df_591['year_month_for_combine'] = pd.to_datetime(df_591['year_month_for_combine'])
# df_591['year_month_for_combine'] = df_591['year_month_for_combine'].dt.to_period('M')
# Out:
# <ipython-input-65-b84b15953eea>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   window_df_591['year_month_for_combine'] = window_df_591['date'].dt.to_period('M')

# %%
df_591 = df_591.merge(window_df_591, right_on='year_month_for_combine', left_on='year_month_for_combine', how='inner')

# %%
df_591.info(max_cols=239)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51073 entries, 0 to 51072
# Data columns (total 211 columns):
#  #    Column                                Non-Null Count  Dtype
# ---   ------                                --------------  -----
#  0    building_age                          51073 non-null  float64
#  1    total_area_ping                       51073 non-null  float64
#  2    community_name                        51073 non-null  int64
#  3    has_parking_space                     51073 non-null  int64
#  4    total_floors                          51073 non-null  float64
#  5    transaction_floors                    51073 non-null  float64
#  6    target_floors                         51073 non-null  float64
#  7    bedrooms                              51073 non-null  float64
#  8    living_rooms                          51073 non-null  float64
#  9    bathrooms                             51073 non-null  float64
#  10   elevator_available                    51073 non-null  int64
#  11   main_building_ratio                   51073 non-null  float64
#  12   new_per_ping                          51073 non-null  float64
#  13   Public_Activity_Space_under_250_m     51073 non-null  float64
#  14   MRT_Exit_under_250_m                  51073 non-null  float64
#  15   Religious_Site_under_250_m            51073 non-null  float64
#  16   School_under_250_m                    51073 non-null  float64
#  17   Kindergarten_under_250_m              51073 non-null  float64
#  18   Convenience_Store_under_250_m         51073 non-null  float64
#  19   Bank_under_250_m                      51073 non-null  float64
#  20   Clinic_under_250_m                    51073 non-null  float64
#  21   Pharmacy_under_250_m                  51073 non-null  float64
#  22   acc_Public_Activity_Space_under_500m  51073 non-null  float64
#  23   acc_Public_Activity_Space_under_750m  51073 non-null  float64
#  24   acc_MRT_Exit_under_500m               51073 non-null  float64
#  25   acc_MRT_Exit_under_750m               51073 non-null  float64
#  26   acc_Religious_Site_under_500m         51073 non-null  float64
#  27   acc_Religious_Site_under_750m         51073 non-null  float64
#  28   acc_Shopping_Area_under_750m          51073 non-null  float64
#  29   acc_School_under_500m                 51073 non-null  float64
#  30   acc_School_under_750m                 51073 non-null  float64
#  31   acc_Hospital_under_500m               51073 non-null  float64
#  32   acc_Hospital_under_750m               51073 non-null  float64
#  33   acc_Gas_Station_under_750m            51073 non-null  float64
#  34   acc_Kindergarten_under_500m           51073 non-null  float64
#  35   acc_Kindergarten_under_750m           51073 non-null  float64
#  36   acc_Daycare_Center_under_500m         51073 non-null  float64
#  37   acc_Daycare_Center_under_750m         51073 non-null  float64
#  38   acc_Convenience_Store_under_500m      51073 non-null  float64
#  39   acc_Convenience_Store_under_750m      51073 non-null  float64
#  40   acc_Bank_under_500m                   51073 non-null  float64
#  41   acc_Bank_under_750m                   51073 non-null  float64
#  42   acc_Police_Station_under_750m         51073 non-null  float64
#  43   acc_Clinic_under_500m                 51073 non-null  float64
#  44   acc_Clinic_under_750m                 51073 non-null  float64
#  45   acc_Pharmacy_under_500m               51073 non-null  float64
#  46   acc_Pharmacy_under_750m               51073 non-null  float64
#  47   acc_Medical_Facility_under_750m       51073 non-null  float64
#  48   property_type__公寓                     51073 non-null  int64
#  49   property_type__透天厝                    51073 non-null  int64
#  50   property_type__電梯大樓                   51073 non-null  int64
#  51   city__台北市                             51073 non-null  int64
#  52   city__新北市                             51073 non-null  int64
#  53   district__三峽區                         51073 non-null  int64
#  54   district__三芝區                         51073 non-null  int64
#  55   district__三重區                         51073 non-null  int64
#  56   district__中和區                         51073 non-null  int64
#  57   district__中山區                         51073 non-null  int64
#  58   district__中正區                         51073 non-null  int64
#  59   district__五股區                         51073 non-null  int64
#  60   district__信義區                         51073 non-null  int64
#  61   district__內湖區                         51073 non-null  int64
#  62   district__八里區                         51073 non-null  int64
#  63   district__北投區                         51073 non-null  int64
#  64   district__南港區                         51073 non-null  int64
#  65   district__土城區                         51073 non-null  int64
#  66   district__坪林區                         51073 non-null  int64
#  67   district__士林區                         51073 non-null  int64
#  68   district__大同區                         51073 non-null  int64
#  69   district__大安區                         51073 non-null  int64
#  70   district__文山區                         51073 non-null  int64
#  71   district__新店區                         51073 non-null  int64
#  72   district__新莊區                         51073 non-null  int64
#  73   district__松山區                         51073 non-null  int64
#  74   district__板橋區                         51073 non-null  int64
#  75   district__林口區                         51073 non-null  int64
#  76   district__樹林區                         51073 non-null  int64
#  77   district__永和區                         51073 non-null  int64
#  78   district__汐止區                         51073 non-null  int64
#  79   district__泰山區                         51073 non-null  int64
#  80   district__淡水區                         51073 non-null  int64
#  81   district__深坑區                         51073 non-null  int64
#  82   district__烏來區                         51073 non-null  int64
#  83   district__瑞芳區                         51073 non-null  int64
#  84   district__石門區                         51073 non-null  int64
#  85   district__萬華區                         51073 non-null  int64
#  86   district__萬里區                         51073 non-null  int64
#  87   district__蘆洲區                         51073 non-null  int64
#  88   district__貢寮區                         51073 non-null  int64
#  89   district__金山區                         51073 non-null  int64
#  90   district__鶯歌區                         51073 non-null  int64
#  91   usage_category__住商用                   51073 non-null  int64
#  92   usage_category__住家用                   51073 non-null  int64
#  93   year_month_for_combine                51073 non-null  period[M]
#  94   date                                  51073 non-null  datetime64[ns]
#  95   target_index_house_index_xyi_all_tp   51073 non-null  float64
#  96   house_index_xyi_all_tp_lag_1          51073 non-null  float64
#  97   house_index_xyi_tp_lag_1              51073 non-null  float64
#  98   house_index_xyi_new_tp_lag_1          51073 non-null  float64
#  99   EB18_lag_1                            51073 non-null  float64
#  100  EB21_lag_1                            51073 non-null  float64
#  101  MC31_lag_1                            51073 non-null  float64
#  102  MC31G_lag_1                           51073 non-null  float64
#  103  MC36_lag_1                            51073 non-null  float64
#  104  NA0101_lag_1                          51073 non-null  float64
#  105  NA1005_lag_1                          51073 non-null  float64
#  106  NB0101_lag_1                          51073 non-null  float64
#  107  NC0117_lag_1                          51073 non-null  float64
#  108  NC0118_lag_1                          51073 non-null  float64
#  109  NE0206_lag_1                          51073 non-null  float64
#  110  PA0120_lag_1                          51073 non-null  float64
#  111  PA1205_lag_1                          51073 non-null  float64
#  112  PE0503_lag_1                          51073 non-null  float64
#  113  TSE收盤_lag_1                           51073 non-null  float64
#  114  水泥(TSE11)收盤_lag_1                     51073 non-null  float64
#  115  建材營造(TSE25)收盤_lag_1                   51073 non-null  float64
#  116  航運業(TSE26)收盤_lag_1                    51073 non-null  float64
#  117  鋼鐵(TSE20)收盤_lag_1                     51073 non-null  float64
#  118  預拌混凝土3000磅台北_lag_1                    51073 non-null  float64
#  119  house_index_xyi_all_tp_lag_2          51073 non-null  float64
#  120  house_index_xyi_tp_lag_2              51073 non-null  float64
#  121  house_index_xyi_new_tp_lag_2          51073 non-null  float64
#  122  EB18_lag_2                            51073 non-null  float64
#  123  EB21_lag_2                            51073 non-null  float64
#  124  MC31_lag_2                            51073 non-null  float64
#  125  MC31G_lag_2                           51073 non-null  float64
#  126  MC36_lag_2                            51073 non-null  float64
#  127  NA0101_lag_2                          51073 non-null  float64
#  128  NA1005_lag_2                          51073 non-null  float64
#  129  NB0101_lag_2                          51073 non-null  float64
#  130  NC0117_lag_2                          51073 non-null  float64
#  131  NC0118_lag_2                          51073 non-null  float64
#  132  NE0206_lag_2                          51073 non-null  float64
#  133  PA0120_lag_2                          51073 non-null  float64
#  134  PA1205_lag_2                          51073 non-null  float64
#  135  PE0503_lag_2                          51073 non-null  float64
#  136  TSE收盤_lag_2                           51073 non-null  float64
#  137  水泥(TSE11)收盤_lag_2                     51073 non-null  float64
#  138  建材營造(TSE25)收盤_lag_2                   51073 non-null  float64
#  139  航運業(TSE26)收盤_lag_2                    51073 non-null  float64
#  140  鋼鐵(TSE20)收盤_lag_2                     51073 non-null  float64
#  141  預拌混凝土3000磅台北_lag_2                    51073 non-null  float64
#  142  house_index_xyi_all_tp_lag_3          51073 non-null  float64
#  143  house_index_xyi_tp_lag_3              51073 non-null  float64
#  144  house_index_xyi_new_tp_lag_3          51073 non-null  float64
#  145  EB18_lag_3                            51073 non-null  float64
#  146  EB21_lag_3                            51073 non-null  float64
#  147  MC31_lag_3                            51073 non-null  float64
#  148  MC31G_lag_3                           51073 non-null  float64
#  149  MC36_lag_3                            51073 non-null  float64
#  150  NA0101_lag_3                          51073 non-null  float64
#  151  NA1005_lag_3                          51073 non-null  float64
#  152  NB0101_lag_3                          51073 non-null  float64
#  153  NC0117_lag_3                          51073 non-null  float64
#  154  NC0118_lag_3                          51073 non-null  float64
#  155  NE0206_lag_3                          51073 non-null  float64
#  156  PA0120_lag_3                          51073 non-null  float64
#  157  PA1205_lag_3                          51073 non-null  float64
#  158  PE0503_lag_3                          51073 non-null  float64
#  159  TSE收盤_lag_3                           51073 non-null  float64
#  160  水泥(TSE11)收盤_lag_3                     51073 non-null  float64
#  161  建材營造(TSE25)收盤_lag_3                   51073 non-null  float64
#  162  航運業(TSE26)收盤_lag_3                    51073 non-null  float64
#  163  鋼鐵(TSE20)收盤_lag_3                     51073 non-null  float64
#  164  預拌混凝土3000磅台北_lag_3                    51073 non-null  float64
#  165  house_index_xyi_all_tp_lag_4          51073 non-null  float64
#  166  house_index_xyi_tp_lag_4              51073 non-null  float64
#  167  house_index_xyi_new_tp_lag_4          51073 non-null  float64
#  168  EB18_lag_4                            51073 non-null  float64
#  169  EB21_lag_4                            51073 non-null  float64
#  170  MC31_lag_4                            51073 non-null  float64
#  171  MC31G_lag_4                           51073 non-null  float64
#  172  MC36_lag_4                            51073 non-null  float64
#  173  NA0101_lag_4                          51073 non-null  float64
#  174  NA1005_lag_4                          51073 non-null  float64
#  175  NB0101_lag_4                          51073 non-null  float64
#  176  NC0117_lag_4                          51073 non-null  float64
#  177  NC0118_lag_4                          51073 non-null  float64
#  178  NE0206_lag_4                          51073 non-null  float64
#  179  PA0120_lag_4                          51073 non-null  float64
#  180  PA1205_lag_4                          51073 non-null  float64
#  181  PE0503_lag_4                          51073 non-null  float64
#  182  TSE收盤_lag_4                           51073 non-null  float64
#  183  水泥(TSE11)收盤_lag_4                     51073 non-null  float64
#  184  建材營造(TSE25)收盤_lag_4                   51073 non-null  float64
#  185  航運業(TSE26)收盤_lag_4                    51073 non-null  float64
#  186  鋼鐵(TSE20)收盤_lag_4                     51073 non-null  float64
#  187  預拌混凝土3000磅台北_lag_4                    51073 non-null  float64
#  188  house_index_xyi_all_tp_lag_5          51073 non-null  float64
#  189  house_index_xyi_tp_lag_5              51073 non-null  float64
#  190  house_index_xyi_new_tp_lag_5          51073 non-null  float64
#  191  EB18_lag_5                            51073 non-null  float64
#  192  EB21_lag_5                            51073 non-null  float64
#  193  MC31_lag_5                            51073 non-null  float64
#  194  MC31G_lag_5                           51073 non-null  float64
#  195  MC36_lag_5                            51073 non-null  float64
#  196  NA0101_lag_5                          51073 non-null  float64
#  197  NA1005_lag_5                          51073 non-null  float64
#  198  NB0101_lag_5                          51073 non-null  float64
#  199  NC0117_lag_5                          51073 non-null  float64
#  200  NC0118_lag_5                          51073 non-null  float64
#  201  NE0206_lag_5                          51073 non-null  float64
#  202  PA0120_lag_5                          51073 non-null  float64
#  203  PA1205_lag_5                          51073 non-null  float64
#  204  PE0503_lag_5                          51073 non-null  float64
#  205  TSE收盤_lag_5                           51073 non-null  float64
#  206  水泥(TSE11)收盤_lag_5                     51073 non-null  float64
#  207  建材營造(TSE25)收盤_lag_5                   51073 non-null  float64
#  208  航運業(TSE26)收盤_lag_5                    51073 non-null  float64
#  209  鋼鐵(TSE20)收盤_lag_5                     51073 non-null  float64
#  210  預拌混凝土3000磅台北_lag_5                    51073 non-null  float64
# dtypes: datetime64[ns](1), float64(161), int64(48), period[M](1)
# memory usage: 82.2 MB

# %%
df_591.drop('date', axis=1, inplace=True)

# %%
df_591.rename(columns={'target_floors': 'target_floor'}, inplace=True)

# %%
df_591_reindex = df_591.reindex(main_df_col_list, axis=1)

# %%
len(main_df_col_list)
# Out:
# 213

# %%
df_591_reindex.fillna(value=0, inplace=True)

# %%
df_591_reindex.info(max_cols=213)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51073 entries, 0 to 51072
# Data columns (total 213 columns):
#  #    Column                                Non-Null Count  Dtype
# ---   ------                                --------------  -----
#  0    community_name                        51073 non-null  int64
#  1    main_building_ratio                   51073 non-null  float64
#  2    building_age                          51073 non-null  float64
#  3    total_area_ping                       51073 non-null  float64
#  4    total_floors                          51073 non-null  float64
#  5    target_floor                          51073 non-null  float64
#  6    transaction_floors                    51073 non-null  float64
#  7    bedrooms                              51073 non-null  float64
#  8    living_rooms                          51073 non-null  float64
#  9    bathrooms                             51073 non-null  float64
#  10   year_month_for_combine                51073 non-null  period[M]
#  11   new_per_ping                          51073 non-null  float64
#  12   Public_Activity_Space_under_250_m     51073 non-null  float64
#  13   MRT_Exit_under_250_m                  51073 non-null  float64
#  14   Religious_Site_under_250_m            51073 non-null  float64
#  15   School_under_250_m                    51073 non-null  float64
#  16   Kindergarten_under_250_m              51073 non-null  float64
#  17   Convenience_Store_under_250_m         51073 non-null  float64
#  18   Bank_under_250_m                      51073 non-null  float64
#  19   Clinic_under_250_m                    51073 non-null  float64
#  20   Pharmacy_under_250_m                  51073 non-null  float64
#  21   acc_Public_Activity_Space_under_500m  51073 non-null  float64
#  22   acc_Public_Activity_Space_under_750m  51073 non-null  float64
#  23   acc_MRT_Exit_under_500m               51073 non-null  float64
#  24   acc_MRT_Exit_under_750m               51073 non-null  float64
#  25   acc_Religious_Site_under_500m         51073 non-null  float64
#  26   acc_Religious_Site_under_750m         51073 non-null  float64
#  27   acc_Shopping_Area_under_750m          51073 non-null  float64
#  28   acc_School_under_500m                 51073 non-null  float64
#  29   acc_School_under_750m                 51073 non-null  float64
#  30   acc_Hospital_under_500m               51073 non-null  float64
#  31   acc_Hospital_under_750m               51073 non-null  float64
#  32   acc_Gas_Station_under_750m            51073 non-null  float64
#  33   acc_Kindergarten_under_500m           51073 non-null  float64
#  34   acc_Kindergarten_under_750m           51073 non-null  float64
#  35   acc_Daycare_Center_under_500m         51073 non-null  float64
#  36   acc_Daycare_Center_under_750m         51073 non-null  float64
#  37   acc_Convenience_Store_under_500m      51073 non-null  float64
#  38   acc_Convenience_Store_under_750m      51073 non-null  float64
#  39   acc_Bank_under_500m                   51073 non-null  float64
#  40   acc_Bank_under_750m                   51073 non-null  float64
#  41   acc_Police_Station_under_750m         51073 non-null  float64
#  42   acc_Clinic_under_500m                 51073 non-null  float64
#  43   acc_Clinic_under_750m                 51073 non-null  float64
#  44   acc_Pharmacy_under_500m               51073 non-null  float64
#  45   acc_Pharmacy_under_750m               51073 non-null  float64
#  46   acc_Medical_Facility_under_750m       51073 non-null  float64
#  47   has_parking_space                     51073 non-null  int64
#  48   elevator_available                    51073 non-null  int64
#  49   property_type__公寓                     51073 non-null  int64
#  50   property_type__透天厝                    51073 non-null  int64
#  51   property_type__電梯大樓                   51073 non-null  int64
#  52   city__台北市                             51073 non-null  int64
#  53   city__新北市                             51073 non-null  int64
#  54   district__三峽區                         51073 non-null  int64
#  55   district__三芝區                         51073 non-null  int64
#  56   district__三重區                         51073 non-null  int64
#  57   district__中和區                         51073 non-null  int64
#  58   district__中山區                         51073 non-null  int64
#  59   district__中正區                         51073 non-null  int64
#  60   district__五股區                         51073 non-null  int64
#  61   district__信義區                         51073 non-null  int64
#  62   district__內湖區                         51073 non-null  int64
#  63   district__八里區                         51073 non-null  int64
#  64   district__北投區                         51073 non-null  int64
#  65   district__南港區                         51073 non-null  int64
#  66   district__土城區                         51073 non-null  int64
#  67   district__坪林區                         51073 non-null  int64
#  68   district__士林區                         51073 non-null  int64
#  69   district__大同區                         51073 non-null  int64
#  70   district__大安區                         51073 non-null  int64
#  71   district__平溪區                         51073 non-null  float64
#  72   district__文山區                         51073 non-null  int64
#  73   district__新店區                         51073 non-null  int64
#  74   district__新莊區                         51073 non-null  int64
#  75   district__松山區                         51073 non-null  int64
#  76   district__板橋區                         51073 non-null  int64
#  77   district__林口區                         51073 non-null  int64
#  78   district__樹林區                         51073 non-null  int64
#  79   district__永和區                         51073 non-null  int64
#  80   district__汐止區                         51073 non-null  int64
#  81   district__泰山區                         51073 non-null  int64
#  82   district__淡水區                         51073 non-null  int64
#  83   district__深坑區                         51073 non-null  int64
#  84   district__烏來區                         51073 non-null  int64
#  85   district__瑞芳區                         51073 non-null  int64
#  86   district__石碇區                         51073 non-null  float64
#  87   district__石門區                         51073 non-null  int64
#  88   district__萬華區                         51073 non-null  int64
#  89   district__萬里區                         51073 non-null  int64
#  90   district__蘆洲區                         51073 non-null  int64
#  91   district__貢寮區                         51073 non-null  int64
#  92   district__金山區                         51073 non-null  int64
#  93   district__雙溪區                         51073 non-null  float64
#  94   district__鶯歌區                         51073 non-null  int64
#  95   usage_category__住商用                   51073 non-null  int64
#  96   usage_category__住家用                   51073 non-null  int64
#  97   target_index_house_index_xyi_all_tp   51073 non-null  float64
#  98   house_index_xyi_all_tp_lag_1          51073 non-null  float64
#  99   house_index_xyi_tp_lag_1              51073 non-null  float64
#  100  house_index_xyi_new_tp_lag_1          51073 non-null  float64
#  101  EB18_lag_1                            51073 non-null  float64
#  102  EB21_lag_1                            51073 non-null  float64
#  103  MC31_lag_1                            51073 non-null  float64
#  104  MC31G_lag_1                           51073 non-null  float64
#  105  MC36_lag_1                            51073 non-null  float64
#  106  NA0101_lag_1                          51073 non-null  float64
#  107  NA1005_lag_1                          51073 non-null  float64
#  108  NB0101_lag_1                          51073 non-null  float64
#  109  NC0117_lag_1                          51073 non-null  float64
#  110  NC0118_lag_1                          51073 non-null  float64
#  111  NE0206_lag_1                          51073 non-null  float64
#  112  PA0120_lag_1                          51073 non-null  float64
#  113  PA1205_lag_1                          51073 non-null  float64
#  114  PE0503_lag_1                          51073 non-null  float64
#  115  TSE收盤_lag_1                           51073 non-null  float64
#  116  水泥(TSE11)收盤_lag_1                     51073 non-null  float64
#  117  建材營造(TSE25)收盤_lag_1                   51073 non-null  float64
#  118  航運業(TSE26)收盤_lag_1                    51073 non-null  float64
#  119  鋼鐵(TSE20)收盤_lag_1                     51073 non-null  float64
#  120  預拌混凝土3000磅台北_lag_1                    51073 non-null  float64
#  121  house_index_xyi_all_tp_lag_2          51073 non-null  float64
#  122  house_index_xyi_tp_lag_2              51073 non-null  float64
#  123  house_index_xyi_new_tp_lag_2          51073 non-null  float64
#  124  EB18_lag_2                            51073 non-null  float64
#  125  EB21_lag_2                            51073 non-null  float64
#  126  MC31_lag_2                            51073 non-null  float64
#  127  MC31G_lag_2                           51073 non-null  float64
#  128  MC36_lag_2                            51073 non-null  float64
#  129  NA0101_lag_2                          51073 non-null  float64
#  130  NA1005_lag_2                          51073 non-null  float64
#  131  NB0101_lag_2                          51073 non-null  float64
#  132  NC0117_lag_2                          51073 non-null  float64
#  133  NC0118_lag_2                          51073 non-null  float64
#  134  NE0206_lag_2                          51073 non-null  float64
#  135  PA0120_lag_2                          51073 non-null  float64
#  136  PA1205_lag_2                          51073 non-null  float64
#  137  PE0503_lag_2                          51073 non-null  float64
#  138  TSE收盤_lag_2                           51073 non-null  float64
#  139  水泥(TSE11)收盤_lag_2                     51073 non-null  float64
#  140  建材營造(TSE25)收盤_lag_2                   51073 non-null  float64
#  141  航運業(TSE26)收盤_lag_2                    51073 non-null  float64
#  142  鋼鐵(TSE20)收盤_lag_2                     51073 non-null  float64
#  143  預拌混凝土3000磅台北_lag_2                    51073 non-null  float64
#  144  house_index_xyi_all_tp_lag_3          51073 non-null  float64
#  145  house_index_xyi_tp_lag_3              51073 non-null  float64
#  146  house_index_xyi_new_tp_lag_3          51073 non-null  float64
#  147  EB18_lag_3                            51073 non-null  float64
#  148  EB21_lag_3                            51073 non-null  float64
#  149  MC31_lag_3                            51073 non-null  float64
#  150  MC31G_lag_3                           51073 non-null  float64
#  151  MC36_lag_3                            51073 non-null  float64
#  152  NA0101_lag_3                          51073 non-null  float64
#  153  NA1005_lag_3                          51073 non-null  float64
#  154  NB0101_lag_3                          51073 non-null  float64
#  155  NC0117_lag_3                          51073 non-null  float64
#  156  NC0118_lag_3                          51073 non-null  float64
#  157  NE0206_lag_3                          51073 non-null  float64
#  158  PA0120_lag_3                          51073 non-null  float64
#  159  PA1205_lag_3                          51073 non-null  float64
#  160  PE0503_lag_3                          51073 non-null  float64
#  161  TSE收盤_lag_3                           51073 non-null  float64
#  162  水泥(TSE11)收盤_lag_3                     51073 non-null  float64
#  163  建材營造(TSE25)收盤_lag_3                   51073 non-null  float64
#  164  航運業(TSE26)收盤_lag_3                    51073 non-null  float64
#  165  鋼鐵(TSE20)收盤_lag_3                     51073 non-null  float64
#  166  預拌混凝土3000磅台北_lag_3                    51073 non-null  float64
#  167  house_index_xyi_all_tp_lag_4          51073 non-null  float64
#  168  house_index_xyi_tp_lag_4              51073 non-null  float64
#  169  house_index_xyi_new_tp_lag_4          51073 non-null  float64
#  170  EB18_lag_4                            51073 non-null  float64
#  171  EB21_lag_4                            51073 non-null  float64
#  172  MC31_lag_4                            51073 non-null  float64
#  173  MC31G_lag_4                           51073 non-null  float64
#  174  MC36_lag_4                            51073 non-null  float64
#  175  NA0101_lag_4                          51073 non-null  float64
#  176  NA1005_lag_4                          51073 non-null  float64
#  177  NB0101_lag_4                          51073 non-null  float64
#  178  NC0117_lag_4                          51073 non-null  float64
#  179  NC0118_lag_4                          51073 non-null  float64
#  180  NE0206_lag_4                          51073 non-null  float64
#  181  PA0120_lag_4                          51073 non-null  float64
#  182  PA1205_lag_4                          51073 non-null  float64
#  183  PE0503_lag_4                          51073 non-null  float64
#  184  TSE收盤_lag_4                           51073 non-null  float64
#  185  水泥(TSE11)收盤_lag_4                     51073 non-null  float64
#  186  建材營造(TSE25)收盤_lag_4                   51073 non-null  float64
#  187  航運業(TSE26)收盤_lag_4                    51073 non-null  float64
#  188  鋼鐵(TSE20)收盤_lag_4                     51073 non-null  float64
#  189  預拌混凝土3000磅台北_lag_4                    51073 non-null  float64
#  190  house_index_xyi_all_tp_lag_5          51073 non-null  float64
#  191  house_index_xyi_tp_lag_5              51073 non-null  float64
#  192  house_index_xyi_new_tp_lag_5          51073 non-null  float64
#  193  EB18_lag_5                            51073 non-null  float64
#  194  EB21_lag_5                            51073 non-null  float64
#  195  MC31_lag_5                            51073 non-null  float64
#  196  MC31G_lag_5                           51073 non-null  float64
#  197  MC36_lag_5                            51073 non-null  float64
#  198  NA0101_lag_5                          51073 non-null  float64
#  199  NA1005_lag_5                          51073 non-null  float64
#  200  NB0101_lag_5                          51073 non-null  float64
#  201  NC0117_lag_5                          51073 non-null  float64
#  202  NC0118_lag_5                          51073 non-null  float64
#  203  NE0206_lag_5                          51073 non-null  float64
#  204  PA0120_lag_5                          51073 non-null  float64
#  205  PA1205_lag_5                          51073 non-null  float64
#  206  PE0503_lag_5                          51073 non-null  float64
#  207  TSE收盤_lag_5                           51073 non-null  float64
#  208  水泥(TSE11)收盤_lag_5                     51073 non-null  float64
#  209  建材營造(TSE25)收盤_lag_5                   51073 non-null  float64
#  210  航運業(TSE26)收盤_lag_5                    51073 non-null  float64
#  211  鋼鐵(TSE20)收盤_lag_5                     51073 non-null  float64
#  212  預拌混凝土3000磅台北_lag_5                    51073 non-null  float64
# dtypes: float64(164), int64(48), period[M](1)
# memory usage: 83.0 MB

# %%
X_591 = df_591_reindex.drop(['new_per_ping', 'year_month_for_combine'], axis=1)
y_591 = df_591_reindex['new_per_ping']

# %%
X_591.info(max_cols=211)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51073 entries, 0 to 51072
# Data columns (total 211 columns):
#  #    Column                                Non-Null Count  Dtype
# ---   ------                                --------------  -----
#  0    community_name                        51073 non-null  int64
#  1    main_building_ratio                   51073 non-null  float64
#  2    building_age                          51073 non-null  float64
#  3    total_area_ping                       51073 non-null  float64
#  4    total_floors                          51073 non-null  float64
#  5    target_floor                          51073 non-null  float64
#  6    transaction_floors                    51073 non-null  float64
#  7    bedrooms                              51073 non-null  float64
#  8    living_rooms                          51073 non-null  float64
#  9    bathrooms                             51073 non-null  float64
#  10   Public_Activity_Space_under_250_m     51073 non-null  float64
#  11   MRT_Exit_under_250_m                  51073 non-null  float64
#  12   Religious_Site_under_250_m            51073 non-null  float64
#  13   School_under_250_m                    51073 non-null  float64
#  14   Kindergarten_under_250_m              51073 non-null  float64
#  15   Convenience_Store_under_250_m         51073 non-null  float64
#  16   Bank_under_250_m                      51073 non-null  float64
#  17   Clinic_under_250_m                    51073 non-null  float64
#  18   Pharmacy_under_250_m                  51073 non-null  float64
#  19   acc_Public_Activity_Space_under_500m  51073 non-null  float64
#  20   acc_Public_Activity_Space_under_750m  51073 non-null  float64
#  21   acc_MRT_Exit_under_500m               51073 non-null  float64
#  22   acc_MRT_Exit_under_750m               51073 non-null  float64
#  23   acc_Religious_Site_under_500m         51073 non-null  float64
#  24   acc_Religious_Site_under_750m         51073 non-null  float64
#  25   acc_Shopping_Area_under_750m          51073 non-null  float64
#  26   acc_School_under_500m                 51073 non-null  float64
#  27   acc_School_under_750m                 51073 non-null  float64
#  28   acc_Hospital_under_500m               51073 non-null  float64
#  29   acc_Hospital_under_750m               51073 non-null  float64
#  30   acc_Gas_Station_under_750m            51073 non-null  float64
#  31   acc_Kindergarten_under_500m           51073 non-null  float64
#  32   acc_Kindergarten_under_750m           51073 non-null  float64
#  33   acc_Daycare_Center_under_500m         51073 non-null  float64
#  34   acc_Daycare_Center_under_750m         51073 non-null  float64
#  35   acc_Convenience_Store_under_500m      51073 non-null  float64
#  36   acc_Convenience_Store_under_750m      51073 non-null  float64
#  37   acc_Bank_under_500m                   51073 non-null  float64
#  38   acc_Bank_under_750m                   51073 non-null  float64
#  39   acc_Police_Station_under_750m         51073 non-null  float64
#  40   acc_Clinic_under_500m                 51073 non-null  float64
#  41   acc_Clinic_under_750m                 51073 non-null  float64
#  42   acc_Pharmacy_under_500m               51073 non-null  float64
#  43   acc_Pharmacy_under_750m               51073 non-null  float64
#  44   acc_Medical_Facility_under_750m       51073 non-null  float64
#  45   has_parking_space                     51073 non-null  int64
#  46   elevator_available                    51073 non-null  int64
#  47   property_type__公寓                     51073 non-null  int64
#  48   property_type__透天厝                    51073 non-null  int64
#  49   property_type__電梯大樓                   51073 non-null  int64
#  50   city__台北市                             51073 non-null  int64
#  51   city__新北市                             51073 non-null  int64
#  52   district__三峽區                         51073 non-null  int64
#  53   district__三芝區                         51073 non-null  int64
#  54   district__三重區                         51073 non-null  int64
#  55   district__中和區                         51073 non-null  int64
#  56   district__中山區                         51073 non-null  int64
#  57   district__中正區                         51073 non-null  int64
#  58   district__五股區                         51073 non-null  int64
#  59   district__信義區                         51073 non-null  int64
#  60   district__內湖區                         51073 non-null  int64
#  61   district__八里區                         51073 non-null  int64
#  62   district__北投區                         51073 non-null  int64
#  63   district__南港區                         51073 non-null  int64
#  64   district__土城區                         51073 non-null  int64
#  65   district__坪林區                         51073 non-null  int64
#  66   district__士林區                         51073 non-null  int64
#  67   district__大同區                         51073 non-null  int64
#  68   district__大安區                         51073 non-null  int64
#  69   district__平溪區                         51073 non-null  float64
#  70   district__文山區                         51073 non-null  int64
#  71   district__新店區                         51073 non-null  int64
#  72   district__新莊區                         51073 non-null  int64
#  73   district__松山區                         51073 non-null  int64
#  74   district__板橋區                         51073 non-null  int64
#  75   district__林口區                         51073 non-null  int64
#  76   district__樹林區                         51073 non-null  int64
#  77   district__永和區                         51073 non-null  int64
#  78   district__汐止區                         51073 non-null  int64
#  79   district__泰山區                         51073 non-null  int64
#  80   district__淡水區                         51073 non-null  int64
#  81   district__深坑區                         51073 non-null  int64
#  82   district__烏來區                         51073 non-null  int64
#  83   district__瑞芳區                         51073 non-null  int64
#  84   district__石碇區                         51073 non-null  float64
#  85   district__石門區                         51073 non-null  int64
#  86   district__萬華區                         51073 non-null  int64
#  87   district__萬里區                         51073 non-null  int64
#  88   district__蘆洲區                         51073 non-null  int64
#  89   district__貢寮區                         51073 non-null  int64
#  90   district__金山區                         51073 non-null  int64
#  91   district__雙溪區                         51073 non-null  float64
#  92   district__鶯歌區                         51073 non-null  int64
#  93   usage_category__住商用                   51073 non-null  int64
#  94   usage_category__住家用                   51073 non-null  int64
#  95   target_index_house_index_xyi_all_tp   51073 non-null  float64
#  96   house_index_xyi_all_tp_lag_1          51073 non-null  float64
#  97   house_index_xyi_tp_lag_1              51073 non-null  float64
#  98   house_index_xyi_new_tp_lag_1          51073 non-null  float64
#  99   EB18_lag_1                            51073 non-null  float64
#  100  EB21_lag_1                            51073 non-null  float64
#  101  MC31_lag_1                            51073 non-null  float64
#  102  MC31G_lag_1                           51073 non-null  float64
#  103  MC36_lag_1                            51073 non-null  float64
#  104  NA0101_lag_1                          51073 non-null  float64
#  105  NA1005_lag_1                          51073 non-null  float64
#  106  NB0101_lag_1                          51073 non-null  float64
#  107  NC0117_lag_1                          51073 non-null  float64
#  108  NC0118_lag_1                          51073 non-null  float64
#  109  NE0206_lag_1                          51073 non-null  float64
#  110  PA0120_lag_1                          51073 non-null  float64
#  111  PA1205_lag_1                          51073 non-null  float64
#  112  PE0503_lag_1                          51073 non-null  float64
#  113  TSE收盤_lag_1                           51073 non-null  float64
#  114  水泥(TSE11)收盤_lag_1                     51073 non-null  float64
#  115  建材營造(TSE25)收盤_lag_1                   51073 non-null  float64
#  116  航運業(TSE26)收盤_lag_1                    51073 non-null  float64
#  117  鋼鐵(TSE20)收盤_lag_1                     51073 non-null  float64
#  118  預拌混凝土3000磅台北_lag_1                    51073 non-null  float64
#  119  house_index_xyi_all_tp_lag_2          51073 non-null  float64
#  120  house_index_xyi_tp_lag_2              51073 non-null  float64
#  121  house_index_xyi_new_tp_lag_2          51073 non-null  float64
#  122  EB18_lag_2                            51073 non-null  float64
#  123  EB21_lag_2                            51073 non-null  float64
#  124  MC31_lag_2                            51073 non-null  float64
#  125  MC31G_lag_2                           51073 non-null  float64
#  126  MC36_lag_2                            51073 non-null  float64
#  127  NA0101_lag_2                          51073 non-null  float64
#  128  NA1005_lag_2                          51073 non-null  float64
#  129  NB0101_lag_2                          51073 non-null  float64
#  130  NC0117_lag_2                          51073 non-null  float64
#  131  NC0118_lag_2                          51073 non-null  float64
#  132  NE0206_lag_2                          51073 non-null  float64
#  133  PA0120_lag_2                          51073 non-null  float64
#  134  PA1205_lag_2                          51073 non-null  float64
#  135  PE0503_lag_2                          51073 non-null  float64
#  136  TSE收盤_lag_2                           51073 non-null  float64
#  137  水泥(TSE11)收盤_lag_2                     51073 non-null  float64
#  138  建材營造(TSE25)收盤_lag_2                   51073 non-null  float64
#  139  航運業(TSE26)收盤_lag_2                    51073 non-null  float64
#  140  鋼鐵(TSE20)收盤_lag_2                     51073 non-null  float64
#  141  預拌混凝土3000磅台北_lag_2                    51073 non-null  float64
#  142  house_index_xyi_all_tp_lag_3          51073 non-null  float64
#  143  house_index_xyi_tp_lag_3              51073 non-null  float64
#  144  house_index_xyi_new_tp_lag_3          51073 non-null  float64
#  145  EB18_lag_3                            51073 non-null  float64
#  146  EB21_lag_3                            51073 non-null  float64
#  147  MC31_lag_3                            51073 non-null  float64
#  148  MC31G_lag_3                           51073 non-null  float64
#  149  MC36_lag_3                            51073 non-null  float64
#  150  NA0101_lag_3                          51073 non-null  float64
#  151  NA1005_lag_3                          51073 non-null  float64
#  152  NB0101_lag_3                          51073 non-null  float64
#  153  NC0117_lag_3                          51073 non-null  float64
#  154  NC0118_lag_3                          51073 non-null  float64
#  155  NE0206_lag_3                          51073 non-null  float64
#  156  PA0120_lag_3                          51073 non-null  float64
#  157  PA1205_lag_3                          51073 non-null  float64
#  158  PE0503_lag_3                          51073 non-null  float64
#  159  TSE收盤_lag_3                           51073 non-null  float64
#  160  水泥(TSE11)收盤_lag_3                     51073 non-null  float64
#  161  建材營造(TSE25)收盤_lag_3                   51073 non-null  float64
#  162  航運業(TSE26)收盤_lag_3                    51073 non-null  float64
#  163  鋼鐵(TSE20)收盤_lag_3                     51073 non-null  float64
#  164  預拌混凝土3000磅台北_lag_3                    51073 non-null  float64
#  165  house_index_xyi_all_tp_lag_4          51073 non-null  float64
#  166  house_index_xyi_tp_lag_4              51073 non-null  float64
#  167  house_index_xyi_new_tp_lag_4          51073 non-null  float64
#  168  EB18_lag_4                            51073 non-null  float64
#  169  EB21_lag_4                            51073 non-null  float64
#  170  MC31_lag_4                            51073 non-null  float64
#  171  MC31G_lag_4                           51073 non-null  float64
#  172  MC36_lag_4                            51073 non-null  float64
#  173  NA0101_lag_4                          51073 non-null  float64
#  174  NA1005_lag_4                          51073 non-null  float64
#  175  NB0101_lag_4                          51073 non-null  float64
#  176  NC0117_lag_4                          51073 non-null  float64
#  177  NC0118_lag_4                          51073 non-null  float64
#  178  NE0206_lag_4                          51073 non-null  float64
#  179  PA0120_lag_4                          51073 non-null  float64
#  180  PA1205_lag_4                          51073 non-null  float64
#  181  PE0503_lag_4                          51073 non-null  float64
#  182  TSE收盤_lag_4                           51073 non-null  float64
#  183  水泥(TSE11)收盤_lag_4                     51073 non-null  float64
#  184  建材營造(TSE25)收盤_lag_4                   51073 non-null  float64
#  185  航運業(TSE26)收盤_lag_4                    51073 non-null  float64
#  186  鋼鐵(TSE20)收盤_lag_4                     51073 non-null  float64
#  187  預拌混凝土3000磅台北_lag_4                    51073 non-null  float64
#  188  house_index_xyi_all_tp_lag_5          51073 non-null  float64
#  189  house_index_xyi_tp_lag_5              51073 non-null  float64
#  190  house_index_xyi_new_tp_lag_5          51073 non-null  float64
#  191  EB18_lag_5                            51073 non-null  float64
#  192  EB21_lag_5                            51073 non-null  float64
#  193  MC31_lag_5                            51073 non-null  float64
#  194  MC31G_lag_5                           51073 non-null  float64
#  195  MC36_lag_5                            51073 non-null  float64
#  196  NA0101_lag_5                          51073 non-null  float64
#  197  NA1005_lag_5                          51073 non-null  float64
#  198  NB0101_lag_5                          51073 non-null  float64
#  199  NC0117_lag_5                          51073 non-null  float64
#  200  NC0118_lag_5                          51073 non-null  float64
#  201  NE0206_lag_5                          51073 non-null  float64
#  202  PA0120_lag_5                          51073 non-null  float64
#  203  PA1205_lag_5                          51073 non-null  float64
#  204  PE0503_lag_5                          51073 non-null  float64
#  205  TSE收盤_lag_5                           51073 non-null  float64
#  206  水泥(TSE11)收盤_lag_5                     51073 non-null  float64
#  207  建材營造(TSE25)收盤_lag_5                   51073 non-null  float64
#  208  航運業(TSE26)收盤_lag_5                    51073 non-null  float64
#  209  鋼鐵(TSE20)收盤_lag_5                     51073 non-null  float64
#  210  預拌混凝土3000磅台北_lag_5                    51073 non-null  float64
# dtypes: float64(163), int64(48)
# memory usage: 82.2 MB

# %%
X_non_time_591 = X_591.iloc[:,0:95]
time_series_591 = X_591.iloc[:,96:]

# %%
X_non_time_591 = mm_scaler_for_non.transform(X_non_time_591)

time_series_591 = scaler_for_time.transform(time_series_591)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
arry_index_v = time_series_591.shape[0] # 抓總筆數   # time_series_591
X_shift_list_591 = []

for each_index in range(arry_index_v):
    # 每一筆資料抓出來
    each_array_v = time_series_591[each_index].reshape(5,23)

    X_shift_list_591.append(each_array_v)

X_times_591 = np.array(X_shift_list_591)
X_times_591.shape
# Out:
# (51073, 5, 23)

# %%
pred_y_591 = model_combined.predict([X_times_591, X_non_time_591])
# Out:
# 1597/1597 [==============================] - 4s 2ms/step

# %%
# NN 的validation跟test是偏像的

print(f"test mae:{mean_absolute_error(pred_y_591, y_591)}")
print(f"test RMSE:{rmse(pred_y_591, y_591)}")
r2_score_linear_train = r2_score(y_591, pred_y_591)
print('R2_score (test): ', r2_score_linear_train)
print('-'*50)
# Out:
# test mae:163501.4109752462
# test RMSE:253952.96536813266
# R2_score (test):  0.42890017531211655
# --------------------------------------------------

# %% [markdown]
# # 將模型檔案載入，繼續訓練

# %%
# 將模型檔案載入
# model_combined = tf.keras.models.load_model('/content/my_drive/MyDrive/BDSE34期末報告_房價/trained_models/c591_CNN_CBAM_v2_best_0710.h5')

# %%
# model_loaded.fit([X_times_train, non_time_train], y_train, epochs=10, batch_size=32, callbacks=[checkpoint_seq])

# %%
# model_loaded.save('/content/my_drive/MyDrive/BDSE34期末報告_房價/trained_models/model_save_test.h5') # 模型的副檔名記得是.h5

# %% [markdown]
# # 處理要stacking的表格

# %%
# pred_df = nn_final_df.copy()

# %%
# pred_df.info(max_cols=213)

# %%
# drop_col = pred_df.iloc[:, 97:].columns

# %%
# pred_df.drop(drop_col, axis=1, inplace=True)

# %%
# pred_y_train = model_combined.predict([X_times_train, non_time_train])
# pred_y_validation = model_combined.predict([X_times_validation, non_time_validation])
# pred_y_test = model_combined.predict([X_times_test, non_time_test])

# %%
# combine_list = list(pred_y_train) + list(pred_y_validation) + list(pred_y_test)

# %%
# pred_df['pred_y_by_NNs'] = combine_list

# %%
# pred_df['pred_y_by_NNs'] = pred_df['pred_y_by_NNs'].astype(int)

# %%
# pred_df.to_csv('/content/my_drive/MyDrive/BDSE34期末報告_房價/all_data/c591_NN_pred_dataframe.csv', encoding='utf-8', index=False)

# %%
# pred_df.info()

# %% [markdown]
# # shap 模型解釋性

# %%
# !pip install shap

# %%
# import shap

# 解釋模型的 SHAP 值
# explainer = shap.KernelExplainer(model_combined.predict, [X_times_train, non_time_train])
# shap_values = explainer.shap_values([X_times_train[:100], non_time_train[:100]])  # 這裡只用前100個樣本進行解釋

# # 繪製 SHAP 值
# shap.summary_plot(shap_values, [X_times_train[:100], non_time_train[:100]])

# %%
# non_time_train.shape

# %%
# X_times_train.shape, non_time_train.shape

# %%
# 使用 DeepExplainer 來解釋模型
# background = [X_times_train[:100], non_time_train[:100]]

# explainer = shap.DeepExplainer(model_combined, background)
# shap_values = explainer.shap_values(background)

# 繪製 SHAP 值
# shap.summary_plot(shap_values[0], X_times_train[:100], feature_names=[f'X_times_{i}' for i in range(X_times_train.shape[1])])
# shap.summary_plot(shap_values[1], non_time_train[:100], feature_names=[f'non_time_{i}' for i in range(non_time_train.shape[1])])

# %%
# import shap

# 使用 DeepExplainer 來解釋模型
# background = [X_times_train[:100], non_time_train[:100]]

# # 初始化 SHAP 解釋器
# explainer = shap.DeepExplainer(model_combined, background)

# # 解釋部分樣本的預測
# sample_data = [X_times_train[:10], non_time_train[:10]]
# shap_values = explainer.shap_values(sample_data)

# # 繪製 SHAP 值
# # 繪製第1個輸入（X_times_train）的 SHAP 值
# shap.summary_plot(shap_values[0], X_times_train[:10].reshape(-1, X_times_train.shape[2]), feature_names=[f'X_times_{i}' for i in range(X_times_train.shape[2])])

# # 繪製第2個輸入（non_time_train）的 SHAP 值
# shap.summary_plot(shap_values[1], non_time_train[:10], feature_names=[f'non_time_{i}' for i in range(non_time_train.shape[1])])
